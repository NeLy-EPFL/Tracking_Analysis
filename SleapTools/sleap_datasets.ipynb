# %%
import sleap

import matplotlib.pyplot as plt
import cv2

import scipy

from pathlib import Path

import numpy as np

# %% [markdown]
# # Data definition

# %%
#labels = sleap.Labels.load_file("/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp")
labels = sleap.Labels.load_file("/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp")

# %%
# Get first frame

frame0 = labels[0]

# %%
# Get instances

instances = frame0.instances

instances
# Out:
# [Instance(video=Video(filename=/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (407.4, 77.0), thorax: (394.7, 79.7), abdomen: (360.8, 80.1), Lhindleg: (379.2, 86.6), Rhindleg: (353.9, 104.4), Rmidleg1: (396.7, 103.1), Rmidleg2: (385.1, 92.1), Lmidleg1: (406.8, 63.7), Lmidleg2: (381.7, 67.7), Rforeleg1: (431.5, 99.7), Rforeleg2: (413.0, 91.8), Rforeleg3: (400.5, 88.6), Lforeleg1: (417.3, 66.2), Lforeleg2: (409.3, 68.1), Lforeleg3: (398.9, 68.1)], track=None),
#  Instance(video=Video(filename=/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (96.5, 244.6), thorax: (104.7, 232.6), abdomen: (116.2, 209.7), Lhindleg: (144.0, 204.8), Rhindleg: (90.2, 193.3), Rmidleg1: (80.0, 212.9), Rmidleg2: (92.3, 222.1), Lmidleg1: (145.3, 248.1), Lmidleg2: (123.9, 236.1), Rforeleg1: (80.3, 256.2), Rforeleg2: (87.3, 244.8), Rforeleg3: (91.5, 236.3), Lforeleg1: (92.8, 260.4), Lforeleg2: (102.6, 254.5), Lforeleg3: (108.1, 245.1)], track=None),
#  Instance(video=Video(filename=/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (392.8, 348.4), thorax: (380.5, 344.9), abdomen: (352.7, 333.6), Lhindleg: (347.1, 316.6), Rhindleg: (330.5, 365.6), Rmidleg1: (351.3, 364.5), Rmidleg2: (369.5, 373.5), Lmidleg1: (380.6, 316.9), Lmidleg2: (376.5, 329.6), Rforeleg1: (416.2, 337.2), Rforeleg2: (414.6, 341.4), Rforeleg3: (407.1, 346.8), Lforeleg1: (411.6, 332.4), Lforeleg2: (399.2, 334.0), Lforeleg3: (385.4, 333.6)], track=None),
#  Instance(video=Video(filename=/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (465.1, 456.7), thorax: (452.7, 460.0), abdomen: (428.2, 459.6), Lhindleg: (404.0, 445.3), Rhindleg: (418.4, 480.8), Rmidleg1: (469.1, 483.1), Rmidleg2: (447.2, 474.2), Lmidleg1: (461.1, 443.9), Lmidleg2: (443.2, 445.3), Rforeleg1: (475.9, 473.7), Rforeleg2: (467.0, 470.3), Rforeleg3: (456.5, 470.1), Lforeleg1: (495.0, 472.0), Lforeleg2: (485.5, 470.1), Lforeleg3: (474.9, 465.9)], track=None),
#  Instance(video=Video(filename=/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (246.4, 581.3), thorax: (233.3, 581.1), abdomen: (200.6, 584.6), Lhindleg: (169.4, 546.1), Rhindleg: (188.4, 600.2), Rmidleg1: (235.5, 605.2), Rmidleg2: (223.9, 596.5), Lmidleg1: (243.9, 568.2), Lmidleg2: (223.2, 569.4), Rforeleg1: (271.6, 608.1), Rforeleg2: (251.6, 600.3), Rforeleg3: (237.6, 593.4), Lforeleg1: (262.6, 570.9), Lforeleg2: (247.8, 573.2), Lforeleg3: (239.8, 573.1)], track=None),
#  Instance(video=Video(filename=/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (240.9, 712.2), thorax: (228.6, 712.2), abdomen: (200.6, 712.3), Lhindleg: (161.2, 699.0), Rhindleg: (182.6, 729.9), Rmidleg1: (226.5, 732.4), Rmidleg2: (217.4, 721.2), Lmidleg1: (208.6, 693.4), Lmidleg2: (213.8, 698.7), Rforeleg1: (252.7, 736.4), Rforeleg2: (241.2, 725.2), Rforeleg3: (232.6, 721.2), Lforeleg1: (262.1, 706.2), Lforeleg2: (251.1, 707.2), Lforeleg3: (240.7, 701.7)], track=None)]

# %%
pts = instances[0].points
# Out:
# (Point(x=407.41283718891845, y=77.01003620408609, visible=True, complete=True),
#  Point(x=394.701859766807, y=79.66270446777344, visible=True, complete=True),
#  Point(x=360.83001708984375, y=80.0587387084961, visible=True, complete=True),
#  Point(x=379.19875931307075, y=86.5589216218517, visible=False, complete=False),
#  Point(x=353.8827291998098, y=104.36387048851765, visible=True, complete=True),
#  Point(x=396.69677043181514, y=103.09089847589414, visible=True, complete=True),
#  Point(x=385.1249694824219, y=92.05375671386719, visible=True, complete=True),
#  Point(x=406.84350516992333, y=63.712748995225006, visible=True, complete=True),
#  Point(x=381.730224609375, y=67.6575698852539, visible=True, complete=True),
#  Point(x=431.53145901509026, y=99.67849731445312, visible=True, complete=True),
#  Point(x=413.0379638671875, y=91.76300811767578, visible=True, complete=True),
#  Point(x=400.5238342285156, y=88.55249786376953, visible=True, complete=True),
#  Point(x=417.2962446873818, y=66.1998597134507, visible=True, complete=True),
#  Point(x=409.2619124119912, y=68.0897216796875, visible=True, complete=True),
#  Point(x=398.92912167850545, y=68.1453857421875, visible=True, complete=True))

# %%
array = instances[0].numpy()

array
# Out:
# rec.array([[407.41283719,  77.0100362 ],
#            [394.70185977,  79.66270447],
#            [360.83001709,  80.05873871],
#            [         nan,          nan],
#            [353.8827292 , 104.36387049],
#            [396.69677043, 103.09089848],
#            [385.12496948,  92.05375671],
#            [406.84350517,  63.712749  ],
#            [381.73022461,  67.65756989],
#            [431.53145902,  99.67849731],
#            [413.03796387,  91.76300812],
#            [400.52383423,  88.55249786],
#            [417.29624469,  66.19985971],
#            [409.26191241,  68.08972168],
#            [398.92912168,  68.14538574]],
#           dtype=float64)

# %%
# Add a new value to the array

array = np.append(array, [0,0])

# %%
instances[0].pts = sleap.Instance.from_numpy(array, skeleton=labels.skeletons[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gq/T/ipykernel_34697/3795832027.py in <module>
# ----> 1 instances[0].pts = sleap.Instance.from_numpy(array, skeleton=labels.skeletons[0])
#
# ~/sleap/sleap/instance.py in from_numpy(cls, points, skeleton, track)
#     967             This is an alias for `Instance.from_pointsarray()`.
#     968         """
# --> 969         return cls.from_pointsarray(points, skeleton, track=track)
#     970
#     971     def _merge_nodes_data(self, base_node: str, merge_node: str):
#
# ~/sleap/sleap/instance.py in from_pointsarray(cls, points, skeleton, track)
#     943                 continue
#     944
# --> 945             predicted_points[node_name] = Point(x=point[0], y=point[1])
#     946
#     947         return cls(points=predicted_points, skeleton=skeleton, track=track)
#
# IndexError: invalid index to scalar variable.

# %%
array
# Out:
# array([407.41283719,  77.0100362 , 394.70185977,  79.66270447,
#        360.83001709,  80.05873871,          nan,          nan,
#        353.8827292 , 104.36387049, 396.69677043, 103.09089848,
#        385.12496948,  92.05375671, 406.84350517,  63.712749  ,
#        381.73022461,  67.65756989, 431.53145902,  99.67849731,
#        413.03796387,  91.76300812, 400.52383423,  88.55249786,
#        417.29624469,  66.19985971, 409.26191241,  68.08972168,
#        398.92912168,  68.14538574,   0.        ,   0.        ])

# %%
instances[5].points[0].y
# Out:
# 712.2476806640625

# %%
frame1 = labels[1]
instances1 = frame1.instances
instances1
# Out:
# [Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (393.8, 712.4), thorax: (380.6, 713.9), abdomen: (353.4, 713.5), Lhindleg: (322.3, 704.1), Rhindleg: (322.7, 690.1), Rmidleg1: (378.5, 733.3), Rmidleg2: (373.5, 725.9), Lmidleg1: (382.0, 669.3), Lmidleg2: (378.8, 685.9), Rforeleg1: (394.5, 729.3), Rforeleg2: (427.7, 735.7), Rforeleg3: (404.0, 732.4), Lforeleg1: (413.6, 696.1), Lforeleg2: (402.7, 702.8), Lforeleg3: (390.3, 703.3)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (616.2, 80.5), thorax: (605.9, 83.0), abdomen: (571.2, 86.7), Lhindleg: (551.6, 67.0), Rhindleg: (543.7, 107.1), Rmidleg1: (592.8, 104.3), Rmidleg2: (599.9, 95.6), Lmidleg1: (586.9, 65.3), Lmidleg2: (578.1, 77.4), Rforeleg1: (634.7, 83.9), Rforeleg2: (625.7, 87.6), Rforeleg3: (619.9, 93.0), Lforeleg1: (635.8, 66.2), Lforeleg2: (614.5, 69.3), Lforeleg3: (606.9, 73.7)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (159.6, 213.5), thorax: (148.0, 215.1), abdomen: (124.1, 220.8), Lhindleg: (87.8, 205.7), Rhindleg: (128.7, 247.2), Rmidleg1: (155.7, 254.4), Rmidleg2: (140.9, 235.9), Lmidleg1: (146.3, 187.3), Lmidleg2: (142.9, 202.7), Rforeleg1: (179.2, 226.1), Rforeleg2: (166.8, 224.4), Rforeleg3: (156.0, 225.0), Lforeleg1: (180.7, 205.9), Lforeleg2: (169.1, 209.2), Lforeleg3: (156.7, 204.3)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (460.8, 340.4), thorax: (444.0, 341.7), abdomen: (420.9, 336.3), Lhindleg: (405.1, 316.4), Rhindleg: (373.4, 365.6), Rmidleg1: (414.7, 370.5), Rmidleg2: (406.8, 358.1), Lmidleg1: (419.2, 315.6), Lmidleg2: (430.1, 327.8), Rforeleg1: (443.0, 354.3), Rforeleg2: (432.1, 352.3), Rforeleg3: (441.6, 365.3), Lforeleg1: (465.4, 319.3), Lforeleg2: (456.5, 327.7), Lforeleg3: (447.9, 328.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (112.9, 449.7), thorax: (119.4, 456.5), abdomen: (141.5, 472.3), Lhindleg: (139.5, 490.0), Rhindleg: (224.8, 453.9), Rmidleg1: (186.1, 433.0), Rmidleg2: (149.2, 445.0), Lmidleg1: (103.0, 488.1), Lmidleg2: (118.9, 481.1), Rforeleg1: (108.4, 434.5), Rforeleg2: (120.4, 445.3), Rforeleg3: (129.7, 447.2), Lforeleg1: (97.1, 463.5), Lforeleg2: (107.5, 465.0), Lforeleg3: (114.3, 463.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (197.0, 584.7), thorax: (182.0, 584.4), abdomen: (148.2, 601.4), Lhindleg: (143.7, 571.8), Rhindleg: (136.2, 635.7), Rmidleg1: (184.8, 621.7), Rmidleg2: (177.0, 609.2), Lmidleg1: (190.5, 571.9), Lmidleg2: (174.1, 578.5), Rforeleg1: (211.5, 606.3), Rforeleg2: (197.5, 599.8), Rforeleg3: (186.3, 599.9), Lforeleg1: (221.3, 584.3), Lforeleg2: (210.3, 591.8), Lforeleg3: (206.1, 588.9)], track=None)]

# %%
# Sort instances by y position
instances1.sort(key=lambda x: x[0].y)
instances1
#instances.sort(key=lambda x: x.centroid[1])
# Out:
# [Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (616.2, 80.5), thorax: (605.9, 83.0), abdomen: (571.2, 86.7), Lhindleg: (551.6, 67.0), Rhindleg: (543.7, 107.1), Rmidleg1: (592.8, 104.3), Rmidleg2: (599.9, 95.6), Lmidleg1: (586.9, 65.3), Lmidleg2: (578.1, 77.4), Rforeleg1: (634.7, 83.9), Rforeleg2: (625.7, 87.6), Rforeleg3: (619.9, 93.0), Lforeleg1: (635.8, 66.2), Lforeleg2: (614.5, 69.3), Lforeleg3: (606.9, 73.7)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (159.6, 213.5), thorax: (148.0, 215.1), abdomen: (124.1, 220.8), Lhindleg: (87.8, 205.7), Rhindleg: (128.7, 247.2), Rmidleg1: (155.7, 254.4), Rmidleg2: (140.9, 235.9), Lmidleg1: (146.3, 187.3), Lmidleg2: (142.9, 202.7), Rforeleg1: (179.2, 226.1), Rforeleg2: (166.8, 224.4), Rforeleg3: (156.0, 225.0), Lforeleg1: (180.7, 205.9), Lforeleg2: (169.1, 209.2), Lforeleg3: (156.7, 204.3)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (460.8, 340.4), thorax: (444.0, 341.7), abdomen: (420.9, 336.3), Lhindleg: (405.1, 316.4), Rhindleg: (373.4, 365.6), Rmidleg1: (414.7, 370.5), Rmidleg2: (406.8, 358.1), Lmidleg1: (419.2, 315.6), Lmidleg2: (430.1, 327.8), Rforeleg1: (443.0, 354.3), Rforeleg2: (432.1, 352.3), Rforeleg3: (441.6, 365.3), Lforeleg1: (465.4, 319.3), Lforeleg2: (456.5, 327.7), Lforeleg3: (447.9, 328.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (112.9, 449.7), thorax: (119.4, 456.5), abdomen: (141.5, 472.3), Lhindleg: (139.5, 490.0), Rhindleg: (224.8, 453.9), Rmidleg1: (186.1, 433.0), Rmidleg2: (149.2, 445.0), Lmidleg1: (103.0, 488.1), Lmidleg2: (118.9, 481.1), Rforeleg1: (108.4, 434.5), Rforeleg2: (120.4, 445.3), Rforeleg3: (129.7, 447.2), Lforeleg1: (97.1, 463.5), Lforeleg2: (107.5, 465.0), Lforeleg3: (114.3, 463.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (197.0, 584.7), thorax: (182.0, 584.4), abdomen: (148.2, 601.4), Lhindleg: (143.7, 571.8), Rhindleg: (136.2, 635.7), Rmidleg1: (184.8, 621.7), Rmidleg2: (177.0, 609.2), Lmidleg1: (190.5, 571.9), Lmidleg2: (174.1, 578.5), Rforeleg1: (211.5, 606.3), Rforeleg2: (197.5, 599.8), Rforeleg3: (186.3, 599.9), Lforeleg1: (221.3, 584.3), Lforeleg2: (210.3, 591.8), Lforeleg3: (206.1, 588.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (393.8, 712.4), thorax: (380.6, 713.9), abdomen: (353.4, 713.5), Lhindleg: (322.3, 704.1), Rhindleg: (322.7, 690.1), Rmidleg1: (378.5, 733.3), Rmidleg2: (373.5, 725.9), Lmidleg1: (382.0, 669.3), Lmidleg2: (378.8, 685.9), Rforeleg1: (394.5, 729.3), Rforeleg2: (427.7, 735.7), Rforeleg3: (404.0, 732.4), Lforeleg1: (413.6, 696.1), Lforeleg2: (402.7, 702.8), Lforeleg3: (390.3, 703.3)], track=None)]

# %%
labels[1].instances
# Out:
# [Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (616.2, 80.5), thorax: (605.9, 83.0), abdomen: (571.2, 86.7), Lhindleg: (551.6, 67.0), Rhindleg: (543.7, 107.1), Rmidleg1: (592.8, 104.3), Rmidleg2: (599.9, 95.6), Lmidleg1: (586.9, 65.3), Lmidleg2: (578.1, 77.4), Rforeleg1: (634.7, 83.9), Rforeleg2: (625.7, 87.6), Rforeleg3: (619.9, 93.0), Lforeleg1: (635.8, 66.2), Lforeleg2: (614.5, 69.3), Lforeleg3: (606.9, 73.7)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (159.6, 213.5), thorax: (148.0, 215.1), abdomen: (124.1, 220.8), Lhindleg: (87.8, 205.7), Rhindleg: (128.7, 247.2), Rmidleg1: (155.7, 254.4), Rmidleg2: (140.9, 235.9), Lmidleg1: (146.3, 187.3), Lmidleg2: (142.9, 202.7), Rforeleg1: (179.2, 226.1), Rforeleg2: (166.8, 224.4), Rforeleg3: (156.0, 225.0), Lforeleg1: (180.7, 205.9), Lforeleg2: (169.1, 209.2), Lforeleg3: (156.7, 204.3)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (460.8, 340.4), thorax: (444.0, 341.7), abdomen: (420.9, 336.3), Lhindleg: (405.1, 316.4), Rhindleg: (373.4, 365.6), Rmidleg1: (414.7, 370.5), Rmidleg2: (406.8, 358.1), Lmidleg1: (419.2, 315.6), Lmidleg2: (430.1, 327.8), Rforeleg1: (443.0, 354.3), Rforeleg2: (432.1, 352.3), Rforeleg3: (441.6, 365.3), Lforeleg1: (465.4, 319.3), Lforeleg2: (456.5, 327.7), Lforeleg3: (447.9, 328.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (112.9, 449.7), thorax: (119.4, 456.5), abdomen: (141.5, 472.3), Lhindleg: (139.5, 490.0), Rhindleg: (224.8, 453.9), Rmidleg1: (186.1, 433.0), Rmidleg2: (149.2, 445.0), Lmidleg1: (103.0, 488.1), Lmidleg2: (118.9, 481.1), Rforeleg1: (108.4, 434.5), Rforeleg2: (120.4, 445.3), Rforeleg3: (129.7, 447.2), Lforeleg1: (97.1, 463.5), Lforeleg2: (107.5, 465.0), Lforeleg3: (114.3, 463.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (197.0, 584.7), thorax: (182.0, 584.4), abdomen: (148.2, 601.4), Lhindleg: (143.7, 571.8), Rhindleg: (136.2, 635.7), Rmidleg1: (184.8, 621.7), Rmidleg2: (177.0, 609.2), Lmidleg1: (190.5, 571.9), Lmidleg2: (174.1, 578.5), Rforeleg1: (211.5, 606.3), Rforeleg2: (197.5, 599.8), Rforeleg3: (186.3, 599.9), Lforeleg1: (221.3, 584.3), Lforeleg2: (210.3, 591.8), Lforeleg3: (206.1, 588.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (393.8, 712.4), thorax: (380.6, 713.9), abdomen: (353.4, 713.5), Lhindleg: (322.3, 704.1), Rhindleg: (322.7, 690.1), Rmidleg1: (378.5, 733.3), Rmidleg2: (373.5, 725.9), Lmidleg1: (382.0, 669.3), Lmidleg2: (378.8, 685.9), Rforeleg1: (394.5, 729.3), Rforeleg2: (427.7, 735.7), Rforeleg3: (404.0, 732.4), Lforeleg1: (413.6, 696.1), Lforeleg2: (402.7, 702.8), Lforeleg3: (390.3, 703.3)], track=None)]

# %% [markdown]
# Notes : 1) It's fairly easy to sort flies instances by their y positions 2) because the subvariables (ex: instances) are symlinked to the original label variable, the orginial can be edited by editing the subvariable.

# %%
len(labels)
# Out:
# 113

# %%
for f in range(len(labels)):
    labels[f].instances.sort(key=lambda x: x[0].y)

# %%
labels[10].plot()

# %%
frame_0 = labels[0]

frame_0
# Out:
# LabeledFrame(video=HDF5Video('/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp'), frame_idx=6254, instances=6)

# %%
img = frame_0.image

img.shape
# Out:
# (832, 832, 1)

# %%
# Reshape img to a 832x832 image
img_shaped = img[0:832, 0:832]

plt.imshow(img_shaped, cmap='gray')

# %% [markdown]
# # Comparison with cropped video

# %%
CropPath = '/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'
# Display the frame 6254 of the video CropPath
cap = cv2.VideoCapture(CropPath)
cap.set(1, 6254)
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# Looking good, do the same with arena 4 which is slightly more distinguishable

# %%
CropPath4 = '/Users/ulric/Movies/TrainingVids/Crops/Arena4/Arena4.mp4'
# Display the frame 6254 of the video CropPath
cap = cv2.VideoCapture(CropPath4)
cap.set(1, 6254)
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# Below I tested shifting by 6 frames, let's see if this is consistent

# %%
cap = cv2.VideoCapture(CropPath4)
cap.set(1, 6254-6)
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# Seems to be! Then shift everything by 6 frames should be simpler than working on subsets of the videos.

# %% [markdown]
#  Let's check the arena 5

# %%
CropPath5 = '/Users/ulric/Movies/TrainingVids/Crops/Arena5/Arena5.mp4'
# Display the frame 6254 of the video CropPath
cap = cv2.VideoCapture(CropPath5)
cap.set(1, 6254)
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# Might be some inconsistency during the writing process. Then better strategy is to use the cropping parameters and generate the cropped frames from the original labeled frames.

# %%
frame_1 = labels[1]

frame_1

img = frame_1.image

img_shaped = img[0:832, 0:832]

plt.imshow(img_shaped, cmap='gray')

# %%
CropPath = '/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'
# Display the frame corresponding to the frame_1 idx of the video CropPath
cap = cv2.VideoCapture(CropPath)
cap.set(1, frame_1.frame_idx-6)
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# There are 6 frames discrepancy between the original and the cropped frames. This is due to the fact that the cropping is done on the original frames, while the labeled frames are generated from the cropped frames. This is not a problem, as long as there is the same discrepancy everywhere.

# %% [markdown]
# Let's check with some other frame closer to the beginning of the video

# %%
# List frames indices from the labels
frame_idx = []
for i in range(len(labels)):
    frame_idx.append(labels[i].frame_idx)
    
frame_idx
# Out:
# [6254,
#  14247,
#  14391,
#  14318,
#  5405,
#  1532,
#  13703,
#  6332,
#  1575,
#  21673,
#  31832,
#  6141,
#  531,
#  13692,
#  504,
#  6612,
#  1714,
#  6298,
#  14587,
#  13506,
#  19162,
#  19135,
#  21484,
#  14454,
#  14499,
#  6293,
#  37779,
#  6247,
#  6157,
#  6405,
#  6309,
#  6664,
#  17626,
#  5730,
#  6169,
#  14769,
#  14350,
#  1516,
#  14397,
#  6209,
#  19350,
#  14267,
#  8829,
#  6115,
#  14690,
#  6443,
#  14673,
#  1520,
#  14290,
#  21917,
#  23248,
#  533,
#  6573,
#  14283,
#  30049,
#  4498,
#  19331,
#  6396,
#  37036,
#  2227,
#  13107,
#  21667,
#  535,
#  14346,
#  6161,
#  6758,
#  6302,
#  26246,
#  19124,
#  6382,
#  6324,
#  13720,
#  13531,
#  6510,
#  6648,
#  1695,
#  4067,
#  19856,
#  30094,
#  19149,
#  6249,
#  39610,
#  1751,
#  14643,
#  529,
#  6356,
#  39255,
#  13834,
#  19300,
#  13717,
#  14734,
#  14621,
#  14381,
#  41468,
#  540,
#  18138,
#  23544,
#  6379,
#  14701,
#  14432,
#  14718,
#  19338,
#  6675,
#  6338,
#  14525,
#  14716,
#  14724,
#  39556,
#  14288,
#  3459,
#  14709,
#  36797,
#  6360]

# %%
min(frame_idx)
# Out:
# 504

# %%
frame_14 = labels[14]

frame_14

img = frame_14.image

img_shaped = img[0:832, 0:832]

plt.imshow(img_shaped, cmap='gray')

# %%
CropPath = '/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'
# Display the frame corresponding to the frame_1 idx of the video CropPath
cap = cv2.VideoCapture(CropPath)
cap.set(1, frame_14.frame_idx-6)
ret, frame = cap.read()
plt.imshow(frame)

# %%
CropPath3 = '/Users/ulric/Movies/TrainingVids/Crops/Arena3/Arena3.mp4'
# Display the frame corresponding to the frame_1 idx of the video CropPath
cap = cv2.VideoCapture(CropPath3)
cap.set(1, frame_14.frame_idx-6)
ret, frame = cap.read()
plt.imshow(frame)

# %% [markdown]
# Ffmpeg can screw up when trimming if I forget a flag to synchronise frames. Most of the time this will happen on the first frames. OpenCV should not have this problem, which explains why the video writing was fine.

# %% [markdown]
# # Add labels to cropped frames

# %% [markdown]
# First work with one frame on one video to make sure the syntax is right.

# %%
#param_path = '/Users/ulric/Movies/TrainingVids/Arena_indices.npy'
param_path = '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Arena_indices.npy'
# Load the parameters
Arena_indices = np.load(param_path, allow_pickle=True)

# Convert it to a list
Arena_indices = Arena_indices.tolist()

Arena_indices
# Out:
# [[22, 147], [148, 272], [275, 399], [402, 525], [527, 651], [654, 778]]

# %% [markdown]
# Generate a test frame

# %%
CropPath = '/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'
# Display the frame corresponding to the frame_1 idx of the video CropPath
cap = cv2.VideoCapture(CropPath)
cap.set(1, frame_1.frame_idx-6)
ret, frame = cap.read()
plt.imshow(frame)

# %%
# get the labels from the original frame
frame_1 = labels[1]

labs = frame_1.instances[0].points

labs
# Out:
# (Point(x=616.235365568833, y=80.47266621059147, visible=True, complete=True),
#  Point(x=605.8985704947609, y=83.01279864206174, visible=True, complete=True),
#  Point(x=571.2020816314765, y=86.65009578451445, visible=True, complete=True),
#  Point(x=551.6473805731755, y=67.02712313685151, visible=True, complete=True),
#  Point(x=543.7047580948876, y=107.11945452357641, visible=True, complete=True),
#  Point(x=592.7687725912031, y=104.27935289408188, visible=True, complete=True),
#  Point(x=599.8553130506389, y=95.61245078413748, visible=True, complete=True),
#  Point(x=586.9168535893444, y=65.3482228321235, visible=False, complete=True),
#  Point(x=578.1283402857892, y=77.36720769448064, visible=False, complete=True),
#  Point(x=634.7350685045404, y=83.90203358819443, visible=True, complete=True),
#  Point(x=625.7380309660454, y=87.58280339656449, visible=True, complete=True),
#  Point(x=619.8545498003081, y=92.9973353813921, visible=True, complete=True),
#  Point(x=635.79582167212, y=66.18064529193711, visible=False, complete=True),
#  Point(x=614.5327971660398, y=69.26364330669581, visible=True, complete=True),
#  Point(x=606.856541649855, y=73.6573655360009, visible=True, complete=True))

# %%
CorrLabs = labs

for i in range(len(labs)):
    CorrLabs[i].y = labs[i].y - Arena_indices[0][0]
# Out:
# (Point(x=616.235365568833, y=58.47266621059147, visible=True, complete=True),
#  Point(x=605.8985704947609, y=61.01279864206174, visible=True, complete=True),
#  Point(x=571.2020816314765, y=64.65009578451445, visible=True, complete=True),
#  Point(x=551.6473805731755, y=45.027123136851515, visible=True, complete=True),
#  Point(x=543.7047580948876, y=85.11945452357641, visible=True, complete=True),
#  Point(x=592.7687725912031, y=82.27935289408188, visible=True, complete=True),
#  Point(x=599.8553130506389, y=73.61245078413748, visible=True, complete=True),
#  Point(x=586.9168535893444, y=43.3482228321235, visible=False, complete=True),
#  Point(x=578.1283402857892, y=55.36720769448064, visible=False, complete=True),
#  Point(x=634.7350685045404, y=61.90203358819443, visible=True, complete=True),
#  Point(x=625.7380309660454, y=65.58280339656449, visible=True, complete=True),
#  Point(x=619.8545498003081, y=70.9973353813921, visible=True, complete=True),
#  Point(x=635.79582167212, y=44.18064529193711, visible=False, complete=True),
#  Point(x=614.5327971660398, y=47.26364330669581, visible=True, complete=True),
#  Point(x=606.856541649855, y=51.657365536000896, visible=True, complete=True))

# %%
pts = frame_1.instances[0].numpy()

# %%
LabFrame = sleap.LabeledFrame(video = sleap.load_video(CropPath), frame_idx = frame_1.frame_idx-6, instances = [sleap.Instance.from_numpy(pts, skeleton=labels.skeletons[0])])


LabFrame
# Out:
# LabeledFrame(video=MediaVideo('/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'), frame_idx=14241, instances=1)

# %% [markdown]
# First converting the instances points as numpy array worked well to be able to associate frame with instances. Now I need to convert them using sleap methods and skeleton definition to have the edges too

# %%
LabFrame.instances
# Out:
# [Instance(video=Video(filename=/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4, shape=(42462, 126, 832, 3), backend=MediaVideo), frame_idx=14241, points=[head: (616.2, 58.5), thorax: (605.9, 61.0), abdomen: (571.2, 64.7), Lhindleg: (551.6, 45.0), Rhindleg: (543.7, 85.1), Rmidleg1: (592.8, 82.3), Rmidleg2: (599.9, 73.6), Rforeleg1: (634.7, 61.9), Rforeleg2: (625.7, 65.6), Rforeleg3: (619.9, 71.0), Lforeleg2: (614.5, 47.3), Lforeleg3: (606.9, 51.7)], track=None)]

# %%
sleap.nn.viz.plot_instance(LabFrame.instances[0])
# Out:
# [[<matplotlib.lines.Line2D at 0x7fad1ac89210>],
#  [<matplotlib.lines.Line2D at 0x7fad1ac89150>],
#  [<matplotlib.lines.Line2D at 0x7fad1ac89c10>],
#  [<matplotlib.lines.Line2D at 0x7fad1ac893d0>],
#  [<matplotlib.lines.Line2D at 0x7face28aa950>],
#  [<matplotlib.lines.Line2D at 0x7face28aaed0>],
#  [<matplotlib.lines.Line2D at 0x7face28aa410>],
#  [<matplotlib.lines.Line2D at 0x7face28aa110>],
#  [<matplotlib.lines.Line2D at 0x7facf8b1f650>],
#  [<matplotlib.lines.Line2D at 0x7facf8b1f090>],
#  [<matplotlib.lines.Line2D at 0x7facf8b1fed0>],
#  [<matplotlib.lines.Line2D at 0x7facf8b1fb90>],
#  [<matplotlib.lines.Line2D at 0x7facf8aff710>],
#  [<matplotlib.lines.Line2D at 0x7facf8aff9d0>]]

# %%
LabFrame.plot()

# %%
labels[1].instances
# Out:
# [Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (393.8, 690.4), thorax: (380.6, 691.9), abdomen: (353.4, 691.5), Lhindleg: (322.3, 682.1), Rhindleg: (322.7, 668.1), Rmidleg1: (378.5, 711.3), Rmidleg2: (373.5, 703.9), Lmidleg1: (382.0, 647.3), Lmidleg2: (378.8, 663.9), Rforeleg1: (394.5, 707.3), Rforeleg2: (427.7, 713.7), Rforeleg3: (404.0, 710.4), Lforeleg1: (413.6, 674.1), Lforeleg2: (402.7, 680.8), Lforeleg3: (390.3, 681.3)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (616.2, 80.5), thorax: (605.9, 83.0), abdomen: (571.2, 86.7), Lhindleg: (551.6, 67.0), Rhindleg: (543.7, 107.1), Rmidleg1: (592.8, 104.3), Rmidleg2: (599.9, 95.6), Lmidleg1: (586.9, 65.3), Lmidleg2: (578.1, 77.4), Rforeleg1: (634.7, 83.9), Rforeleg2: (625.7, 87.6), Rforeleg3: (619.9, 93.0), Lforeleg1: (635.8, 66.2), Lforeleg2: (614.5, 69.3), Lforeleg3: (606.9, 73.7)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (159.6, 213.5), thorax: (148.0, 215.1), abdomen: (124.1, 220.8), Lhindleg: (87.8, 205.7), Rhindleg: (128.7, 247.2), Rmidleg1: (155.7, 254.4), Rmidleg2: (140.9, 235.9), Lmidleg1: (146.3, 187.3), Lmidleg2: (142.9, 202.7), Rforeleg1: (179.2, 226.1), Rforeleg2: (166.8, 224.4), Rforeleg3: (156.0, 225.0), Lforeleg1: (180.7, 205.9), Lforeleg2: (169.1, 209.2), Lforeleg3: (156.7, 204.3)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (460.8, 340.4), thorax: (444.0, 341.7), abdomen: (420.9, 336.3), Lhindleg: (405.1, 316.4), Rhindleg: (373.4, 365.6), Rmidleg1: (414.7, 370.5), Rmidleg2: (406.8, 358.1), Lmidleg1: (419.2, 315.6), Lmidleg2: (430.1, 327.8), Rforeleg1: (443.0, 354.3), Rforeleg2: (432.1, 352.3), Rforeleg3: (441.6, 365.3), Lforeleg1: (465.4, 319.3), Lforeleg2: (456.5, 327.7), Lforeleg3: (447.9, 328.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (112.9, 449.7), thorax: (119.4, 456.5), abdomen: (141.5, 472.3), Lhindleg: (139.5, 490.0), Rhindleg: (224.8, 453.9), Rmidleg1: (186.1, 433.0), Rmidleg2: (149.2, 445.0), Lmidleg1: (103.0, 488.1), Lmidleg2: (118.9, 481.1), Rforeleg1: (108.4, 434.5), Rforeleg2: (120.4, 445.3), Rforeleg3: (129.7, 447.2), Lforeleg1: (97.1, 463.5), Lforeleg2: (107.5, 465.0), Lforeleg3: (114.3, 463.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=14247, points=[head: (197.0, 584.7), thorax: (182.0, 584.4), abdomen: (148.2, 601.4), Lhindleg: (143.7, 571.8), Rhindleg: (136.2, 635.7), Rmidleg1: (184.8, 621.7), Rmidleg2: (177.0, 609.2), Lmidleg1: (190.5, 571.9), Lmidleg2: (174.1, 578.5), Rforeleg1: (211.5, 606.3), Rforeleg2: (197.5, 599.8), Rforeleg3: (186.3, 599.9), Lforeleg1: (221.3, 584.3), Lforeleg2: (210.3, 591.8), Lforeleg3: (206.1, 588.9)], track=None)]

# %%
labels[1].plot()

# %% [markdown]
# ### Important note: the labels are not sorted by value but by the order they were added to the frame. Frames need to be sorted by y value before processing.

# %% [markdown]
# # Repeat the same procedure with all the crops of the same frame

# %%
# Reload the original labels for a fresh start

labels = sleap.Labels.load_file("/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp")
#labels = sleap.Labels.load_file("/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp")

for f in range(len(labels)):
    labels[f].instances.sort(key=lambda x: x[0].y)

# First define which frame it is : same as the original frame - 6


frame_idx = labels[1].frame_idx - 6

# Create the dataset

CropLabsData = []

#LabFrame = sleap.io.dataset.LabeledFrameDataset(labels, video_paths = [CropPath], frame_indices = [frame_idx])

# %%
#param_path = '/Users/ulric/Movies/TrainingVids/Arena_indices.npy'
param_path = '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Arena_indices.npy'
# Load the parameters
Arena_indices = np.load(param_path, allow_pickle=True)

# Convert it to a list
Arena_indices = Arena_indices.tolist()

Arena_indices
# Out:
# [[22, 147], [148, 272], [275, 399], [402, 525], [527, 651], [654, 778]]

# %%
# get all first values of elements in Arena_indices
Crops_adjust = [x[0] for x in Arena_indices]
Crops_adjust
# Out:
# [22, 148, 275, 402, 527, 654]

# %%
# Get the path to all the videos in the /Users/ulric/Movies/TrainingVids/Crops folder
PathToCrops = Path("/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/")
VidPaths = PathToCrops.rglob("*.mp4")
# Put the path to the videos in a list
CropVids = [vid.as_posix() for vid in VidPaths]
# Sort the list
CropVids.sort()
CropVids
# Out:
# ['/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4',
#  '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4',
#  '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4',
#  '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4',
#  '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4',
#  '/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4']

# %% [markdown]
# Below I tried embedding this in a dataset, but video referencing was bad. Instead I'll first create the dataset then fill it with labeled frames.

# %%
vids = [sleap.load_video(v) for v in CropVids]
vids

Training_data_Cropped = sleap.io.dataset.Labels(
    labeled_frames = [],
    videos = vids,
    skeletons = labels.skeletons,
)

Training_data_Cropped
# Out:
# Labels(labeled_frames=0, videos=6, skeletons=1, tracks=0)

# %%
Training_data_Cropped.videos[1]
# Out:
# Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last'))

# %%
# This chunk of code is to adjust the labels to the cropped videos : For each labeled frame, for each instance in this labeled frame, for each point in these instances, adjust the y coordinate by the corresponding value in Crops_adjust
for f in range(len(labels)):
    frame = labels[f]
    for i in range(len(frame.instances)):
        inst = frame.instances[i]
        for j in range(len(inst.points)):
            inst.points[j].y = inst.points[j].y - Crops_adjust[i]
        pts = inst.numpy()
        Training_data_Cropped.labeled_frames.append(sleap.LabeledFrame(
        video = Training_data_Cropped.videos[i], 
        frame_idx = labels[f].frame_idx-6, 
        instances = [sleap.Instance.from_numpy(pts, skeleton=labels.skeletons[0])]))

# %%
Training_data_Cropped
# Out:
# Labels(labeled_frames=677, videos=6, skeletons=1, tracks=0)

# %%
Training_data_Cropped[0].plot()

# %% [markdown]
# Weird, the labels seem to be shifted as if they were already good but by adjusting them I messed them up.
#
# *warning* : Always reload original dataset otherwise adjustments will be kept from previous runs

# %%
CropLabsData[258].plot()

# %% [markdown]
# ## Bonus : make it a proper dataset

# %% [markdown]
# Right now it is a list of individual labeled frames, there must be a better way to implement this

# %%
labels
# Out:
# Labels(labeled_frames=113, videos=1, skeletons=1, tracks=0)

# %%
labels.video
# Out:
# Video(backend=HDF5Video(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/LabeledFrames.train.pkg.slp', dataset='video0/video', input_format='channels_last', convert_range=False))

# %%
Training_data_Cropped = sleap.io.dataset.Labels(
    #labeled_frames = CropLabsData,
    videos = vids,
    skeletons = labels.skeletons,
)

Training_data_Cropped

# %%
CropLabsData
# Out:
# [LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=6248, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=6248, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=6248, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=6248, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=6248, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=6248, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=14241, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=14241, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=14241, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=14241, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=14241, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=14241, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=14385, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=14385, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=14385, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=14385, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=14385, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=14385, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=14312, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=14312, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=14312, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=14312, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=14312, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=14312, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=5399, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=5399, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=5399, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=5399, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=5399, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=5399, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=1526, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=1526, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=1526, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=1526, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=1526, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=1526, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=13697, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=13697, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=13697, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=13697, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=13697, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=13697, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=6326, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=6326, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=6326, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=6326, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=6326, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=6326, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=1569, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=1569, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=1569, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=1569, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=1569, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=1569, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=21667, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=21667, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=21667, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=21667, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=21667, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=21667, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=31826, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=31826, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=31826, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=31826, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=31826, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=31826, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=6135, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=6135, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=6135, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=6135, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=6135, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=6135, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=525, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=525, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx
instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4'), frame_idx=6354, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4'), frame_idx=6354, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4'), frame_idx=6354, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4'), frame_idx=6354, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4'), frame_idx=6354, instances=1),
#  LabeledFrame(video=MediaVideo('/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4'), frame_idx=6354, instances=1)]

# %% [markdown]
# I just need to embed this in a Dataset class and it should be good to go

# %%
vids = [sleap.load_video(v) for v in CropVids]
vids
# Out:
# [Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last'))]

# %%
Training_data_Cropped = sleap.io.dataset.Labels(
    labeled_frames = CropLabsData,
    #videos = vids,
    skeletons = labels.skeletons,
)

Training_data_Cropped
# Out:
# Labels(labeled_frames=677, videos=677, skeletons=1, tracks=0)

# %%
Training_data_Cropped.videos
# Out:
# [Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
# ...
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last'))]

# %%
Training_data_Cropped.videos = vids

Training_data_Cropped.videos
# Out:
# [Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena1/Arena1.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena2/Arena2.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena3/Arena3.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena4/Arena4.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena5/Arena5.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last')),
#  Video(backend=MediaVideo(filename='/mnt/labserver/DURRIEU_Matthias/Code/Sleap_Pretrained_Maxime/TrainingVideo/Crops/Arena6/Arena6.mp4', grayscale=False, bgr=True, dataset='', input_format='channels_last'))]

# %%
# Save the dataset

Training_data_Cropped.save("/mnt/labserver/DURRIEU_Matthias/Code/Training_data_Cropped.train.pkg.slp")

#sleap.save(Training_data_Cropped, "/Volumes/Ramdya-Lab/DURRIEU_Matthias/Code/Training_data_Cropped.train.pkg.slp")

# %% [markdown]
# # How to get the different instances

# %%
LabsFly1 = frame_0.instances[0]

LabsFly1
# Out:
# Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (407.4, 77.0), thorax: (394.7, 79.7), abdomen: (360.8, 80.1), Lhindleg: (379.2, 86.6), Rhindleg: (353.9, 104.4), Rmidleg1: (396.7, 103.1), Rmidleg2: (385.1, 92.1), Lmidleg1: (406.8, 63.7), Lmidleg2: (381.7, 67.7), Rforeleg1: (431.5, 99.7), Rforeleg2: (413.0, 91.8), Rforeleg3: (400.5, 88.6), Lforeleg1: (417.3, 66.2), Lforeleg2: (409.3, 68.1), Lforeleg3: (398.9, 68.1)], track=None)

# %% [markdown]
# ## How to edit labels in an instance

# %%
# modify the instance
# Add 200 to the y coordinate of each point
for p in range(len(LabsFly1.points)):
    LabsFly1.points[p].y = LabsFly1.points[p].y + 200
    
LabsFly1


#ModInst = i + 200 for i in frame_0.instances[0].points
# Out:
# Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (407.4, 277.0), thorax: (394.7, 279.7), abdomen: (360.8, 280.1), Lhindleg: (379.2, 286.6), Rhindleg: (353.9, 304.4), Rmidleg1: (396.7, 303.1), Rmidleg2: (385.1, 292.1), Lmidleg1: (406.8, 263.7), Lmidleg2: (381.7, 267.7), Rforeleg1: (431.5, 299.7), Rforeleg2: (413.0, 291.8), Rforeleg3: (400.5, 288.6), Lforeleg1: (417.3, 266.2), Lforeleg2: (409.3, 268.1), Lforeleg3: (398.9, 268.1)], track=None)

# %% [markdown]
# ## How to edit all instances

# %%
Insts = frame_0.instances
Insts
# Out:
# [Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (407.4, 277.0), thorax: (394.7, 279.7), abdomen: (360.8, 280.1), Lhindleg: (379.2, 286.6), Rhindleg: (353.9, 304.4), Rmidleg1: (396.7, 303.1), Rmidleg2: (385.1, 292.1), Lmidleg1: (406.8, 263.7), Lmidleg2: (381.7, 267.7), Rforeleg1: (431.5, 299.7), Rforeleg2: (413.0, 291.8), Rforeleg3: (400.5, 288.6), Lforeleg1: (417.3, 266.2), Lforeleg2: (409.3, 268.1), Lforeleg3: (398.9, 268.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (96.5, 244.6), thorax: (104.7, 232.6), abdomen: (116.2, 209.7), Lhindleg: (144.0, 204.8), Rhindleg: (90.2, 193.3), Rmidleg1: (80.0, 212.9), Rmidleg2: (92.3, 222.1), Lmidleg1: (145.3, 248.1), Lmidleg2: (123.9, 236.1), Rforeleg1: (80.3, 256.2), Rforeleg2: (87.3, 244.8), Rforeleg3: (91.5, 236.3), Lforeleg1: (92.8, 260.4), Lforeleg2: (102.6, 254.5), Lforeleg3: (108.1, 245.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (392.8, 348.4), thorax: (380.5, 344.9), abdomen: (352.7, 333.6), Lhindleg: (347.1, 316.6), Rhindleg: (330.5, 365.6), Rmidleg1: (351.3, 364.5), Rmidleg2: (369.5, 373.5), Lmidleg1: (380.6, 316.9), Lmidleg2: (376.5, 329.6), Rforeleg1: (416.2, 337.2), Rforeleg2: (414.6, 341.4), Rforeleg3: (407.1, 346.8), Lforeleg1: (411.6, 332.4), Lforeleg2: (399.2, 334.0), Lforeleg3: (385.4, 333.6)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (465.1, 456.7), thorax: (452.7, 460.0), abdomen: (428.2, 459.6), Lhindleg: (404.0, 445.3), Rhindleg: (418.4, 480.8), Rmidleg1: (469.1, 483.1), Rmidleg2: (447.2, 474.2), Lmidleg1: (461.1, 443.9), Lmidleg2: (443.2, 445.3), Rforeleg1: (475.9, 473.7), Rforeleg2: (467.0, 470.3), Rforeleg3: (456.5, 470.1), Lforeleg1: (495.0, 472.0), Lforeleg2: (485.5, 470.1), Lforeleg3: (474.9, 465.9)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (246.4, 581.3), thorax: (233.3, 581.1), abdomen: (200.6, 584.6), Lhindleg: (169.4, 546.1), Rhindleg: (188.4, 600.2), Rmidleg1: (235.5, 605.2), Rmidleg2: (223.9, 596.5), Lmidleg1: (243.9, 568.2), Lmidleg2: (223.2, 569.4), Rforeleg1: (271.6, 608.1), Rforeleg2: (251.6, 600.3), Rforeleg3: (237.6, 593.4), Lforeleg1: (262.6, 570.9), Lforeleg2: (247.8, 573.2), Lforeleg3: (239.8, 573.1)], track=None),
#  Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (240.9, 712.2), thorax: (228.6, 712.2), abdomen: (200.6, 712.3), Lhindleg: (161.2, 699.0), Rhindleg: (182.6, 729.9), Rmidleg1: (226.5, 732.4), Rmidleg2: (217.4, 721.2), Lmidleg1: (208.6, 693.4), Lmidleg2: (213.8, 698.7), Rforeleg1: (252.7, 736.4), Rforeleg2: (241.2, 725.2), Rforeleg3: (232.6, 721.2), Lforeleg1: (262.1, 706.2), Lforeleg2: (251.1, 707.2), Lforeleg3: (240.7, 701.7)], track=None)]

# %%
for i in range(len(Insts)):
    Fly = Insts[i]
    for p in range(len(Fly.points)):
        Fly.points[p].y = Fly.points[p].y + 200
        
Insts
# Out:
# [Instance(video=Video(filename=/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx
Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp, shape=(113, 832, 832, 1), backend=HDF5Video), frame_idx=6254, points=[head: (240.9, 912.2), thorax: (228.6, 912.2), abdomen: (200.6, 912.3), Lhindleg: (161.2, 899.0), Rhindleg: (182.6, 929.9), Rmidleg1: (226.5, 932.4), Rmidleg2: (217.4, 921.2), Lmidleg1: (208.6, 893.4), Lmidleg2: (213.8, 898.7), Rforeleg1: (252.7, 936.4), Rforeleg2: (241.2, 925.2), Rforeleg3: (232.6, 921.2), Lforeleg1: (262.1, 906.2), Lforeleg2: (251.1, 907.2), Lforeleg3: (240.7, 901.7)], track=None)]

# %% [markdown]
# # Crop the frames according to arenas

# %%
#im_full_gray = cv2.cvtColor(img_shaped, cv2.COLOR_BGR2GRAY)

plt.figure()
plt.imshow(img_shaped, cmap="gray", vmin=0, vmax=255)

# %%
rows = img_shaped.sum(axis=1)

# convert rows to a list
[rows]

#plt.plot(rows)
# Out:
# [array([[34977],
#         [20823],
#         [18491],
#         [24668],
#         [17912],
#         [19334],
#         [39127],
#         [ 8849],
#         [11145],
#         [11590],
#         [11737],
#         [11910],
#         [11926],
#         [12052],
#         [12197],
#         [12246],
#         [12377],
#         [12409],
#         [12477],
#         [12491],
#         [12698],
#         [12712],
#         [12731],
#         [12826],
#         [12794],
#         [12769],
#         [12937],
#         [13020],
#         [13366],
#         [13924],
#         [14425],
#         [14373],
#         [13939],
#         [13541],
#         [13413],
#         [13356],
#         [13506],
#         [13583],
#         [13582],
#         [13609],
#         [13469],
#         [13541],
#         [13547],
#         [13436],
#         [13342],
#         [13301],
#         [13244],
#         [13121],
#         [13047],
#         [13041],
#         [12983],
#         [13022],
#         [13060],
#         [13153],
#         [13349],
#         [13644],
#         [13931],
#         [14652],
#         [16688],
#         [20184],
#         [25722],
#         [33315],
#         [38333],
#         [34921],
#         [27245],
#         [21861],
#         [19321],
#         [18297],
#         [18267],
#         [18465],
#         [18801],
#         [18969],
#         [19026],
#         [19216],
#         [19463],
#         [19866],
#         [20401],
#         [20863],
#         [21273],
#         [21414],
#         [21972],
#         [22294],
#         [22592],
#         [22820],
#         [22789],
#         [22762],
#         [22735],
#         [22838],
#         [22655],
#         [22752],
#         [22748],
#         [22674],
#         [22608],
#         [22241],
#         [21413],
#         [20283],
#         [19362],
#         [19332],
#         [19398],
#         [19643],
#         [19946],
#         [20213],
#         [20524],
#         [20578],
#         [21726],
#         [24074],
#         [27477],
#         [30866],
#         [31337],
#         [27181],
#         [21508],
#         [17890],
#         [16244],
#         [15738],
#         [15379],
#         [15222],
#         [15230],
#         [15195],
#         [15143],
#         [15165],
#         [15070],
#         [15143],
#         [15276],
#         [15440],
#         [15558],
#         [15569],
#         [15581],
#         [15543],
#         [15602],
#         [15648],
#         [15685],
#         [15713],
#         [15716],
#         [15828],
#         [16168],
#         [16531],
#         [17058],
#         [16551],
#         [15899],
#         [15468],
#         [15255],
#         [15119],
#         [15131],
#         [15187],
#         [15156],
#         [15084],
#         [15040],
#         [14969],
#         [14909],
#         [14719],
#         [14646],
#         [14637],
#         [14567],
#         [14829],
#         [15211],
#         [15999],
#         [17420],
#         [19377],
#         [19860],
#         [18310],
#         [16953],
#         [16203],
#         [15930],
#         [15739],
#         [15418],
#         [15179],
#         [15015],
#         [14996],
#         [14723],
#         [14688],
#         [14732],
#         [14854],
#         [15074],
#         [15257],
#         [15527],
#         [15636],
#         [15718],
#         [20687],
#         [20436],
#         [19974],
#         [19479],
#         [19336],
#         [19158],
#         [19054],
#         [18914],
#         [18803],
#         [18925],
#         [19089],
#         [19216],
#         [19223],
#         [19299],
#         [19417],
#         [19670],
#         [20074],
#         [20260],
#         [20540],
#         [20874],
#         [21364],
#         [21937],
#         [23129],
#         [24982],
#         [25581],
#         [23959],
#         [22122],
#         [21206],
#         [20661],
#         [20473],
#         [20172],
#         [20112],
#         [20067],
#         [19871],
#         [19775],
#         [19818],
#         [19965],
#         [19912],
#         [19771],
#         [19576],
#         [19549],
#         [19550],
#         [19974],
#         [20887],
#         [22669],
#         [23698],
#         [23247],
#         [21633],
#         [20410],
#         [19688],
#         [19390],
#         [19239],
#         [19126],
#         [19068],
#         [18861],
#         [18683],
#         [18499],
#         [18404],
#         [18351],
#         [18402],
#         [18351],
#         [18214],
#         [18012],
#         [18038],
#         [17999],
#         [17950],
#         [17915],
#         [17994],
#         [18233],
#         [18606],
#         [19587],
#         [21894],
#         [26580],
#         [35412],
#         [48713],
#         [61297],
#         [63466],
#         [53385],
#         [42195],
#         [34918],
#         [30738],
#         [29298],
#         [29284],
#         [29501],
#         [29528],
#         [29488],
#         [29687],
#         [29792],
#         [29931],
#         [30302],
#         [30371],
#         [30146],
#         [29673],
#         [29530],
#         [29442],
#         [29248],
#         [28945],
#         [28752],
#         [28463],
#         [28101],
#         [27637],
#         [27264],
#         [26488],
#         [25800],
#         [25423],
#         [24995],
#         [24743],
#         [24384],
#         [24107],
#         [23510],
#         [22869],
#         [22586],
#         [22595],
#         [22835],
#         [23220],
#         [23961],
#         [25270],
#         [27420],
#         [32113],
#         [39333],
#         [49572],
#         [55801],
#         [48115],
#         [36325],
#         [27779],
#         [23117],
#         [21355],
#         [21021],
#         [20607],
#         [20283],
#         [19903],
#         [19678],
#         [19552],
#         [19478],
#         [19465],
#         [19576],
#         [19573],
#         [19594],
#         [19615],
#         [19651],
#         [19632],
#         [19690],
#         [19644],
#         [19802],
#         [20061],
#         [20229],
#         [20483],
#         [20842],
#         [21471],
#         [22118],
#         [23019],
#         [22979],
#         [22126],
#         [21265],
#         [20699],
#         [20449],
#         [20381],
#         [20338],
#         [20277],
#         [20223],
#         [20282],
#         [20395],
#         [20352],
#         [20272],
#         [20215],
#         [20249],
#         [20186],
#         [20180],
#         [20122],
#         [20132],
#         [20156],
#         [20141],
#         [20080],
#         [20047],
#         [19908],
#         [19788],
#         [19690],
#         [19588],
#         [19567],
#         [19538],
#         [19467],
#         [19443],
#         [19349],
#         [19342],
#         [19451],
#         [19451],
#         [19600],
#         [19571],
#         [19415],
#         [19224],
#         [19019],
#         [18974],
#         [19081],
#         [19163],
#         [19215],
#         [19175],
#         [19186],
#         [19166],
#         [19075],
#         [19096],
#         [19072],
#         [19031],
#         [19051],
#         [19007],
#         [19038],
#         [19076],
#         [18874],
#         [18798],
#         [18727],
#         [18774],
#         [18780],
#         [18865],
#         [19714],
#         [20983]], dtype=uint64)]

# %%
peaks = scipy.signal.find_peaks(rows,
                                distance=40,
                                height=30_000,)

# Check that peaks are correctly located

x = np.array(range(0,len(rows[0])))
PeaksPos = (x[peaks[0]], rows[0][peaks[0]])

plt.plot(rows)
plt.scatter(PeaksPos[0], PeaksPos[1])
plt.show()
#hv.Histogram(rows).opts(tools=['hover'])*hv.Points(PeaksPos).opts(color='orange', tools=['hover'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gq/T/ipykernel_33988/1784310850.py in <module>
#       1 peaks = scipy.signal.find_peaks(rows,
#       2                                 distance=40,
# ----> 3                                 height=30_000,)
#       4
#       5 # Check that peaks are correctly located
#
# /opt/miniconda3/envs/sleap/lib/python3.7/site-packages/scipy/signal/_peak_finding.py in find_peaks(x, height, threshold, distance, prominence, width, wlen, rel_height, plateau_size)
#     930     """
#     931     # _argmaxima1d expects array of dtype 'float64'
# --> 932     x = _arg_x_as_expected(x)
#     933     if distance is not None and distance < 1:
#     934         raise ValueError('`distance` must be greater or equal to 1')
#
# /opt/miniconda3/envs/sleap/lib/python3.7/site-packages/scipy/signal/_peak_finding.py in _arg_x_as_expected(value)
#     261     value = np.asarray(value, order='C', dtype=np.float64)
#     262     if value.ndim != 1:
# --> 263         raise ValueError('`x` must be a 1-D array')
#     264     return value
#     265
#
# ValueError: `x` must be a 1-D array

# %%
rows[:]
# Out:
# array([[34977],
#        [20823],
#        [18491],
#        [24668],
#        [17912],
#        [19334],
#        [39127],
#        [ 8849],
#        [11145],
#        [11590],
#        [11737],
#        [11910],
#        [11926],
#        [12052],
#        [12197],
#        [12246],
#        [12377],
#        [12409],
#        [12477],
#        [12491],
#        [12698],
#        [12712],
#        [12731],
#        [12826],
#        [12794],
#        [12769],
#        [12937],
#        [13020],
#        [13366],
#        [13924],
#        [14425],
#        [14373],
#        [13939],
#        [13541],
#        [13413],
#        [13356],
#        [13506],
#        [13583],
#        [13582],
#        [13609],
#        [13469],
#        [13541],
#        [13547],
#        [13436],
#        [13342],
#        [13301],
#        [13244],
#        [13121],
#        [13047],
#        [13041],
#        [12983],
#        [13022],
#        [13060],
#        [13153],
#        [13349],
#        [13644],
#        [13931],
#        [14652],
#        [16688],
#        [20184],
#        [25722],
#        [33315],
#        [38333],
#        [34921],
#        [27245],
#        [21861],
#        [19321],
#        [18297],
#        [18267],
#        [18465],
#        [18801],
#        [18969],
#        [19026],
#        [19216],
#        [19463],
#        [19866],
#        [20401],
#        [20863],
#        [21273],
#        [21414],
#        [21972],
#        [22294],
#        [22592],
#        [22820],
#        [22789],
#        [22762],
#        [22735],
#        [22838],
#        [22655],
#        [22752],
#        [22748],
#        [22674],
#        [22608],
#        [22241],
#        [21413],
#        [20283],
#        [19362],
#        [19332],
#        [19398],
#        [19643],
#        [19946],
#        [20213],
#        [20524],
#        [20578],
#        [21726],
#        [24074],
#        [27477],
#        [30866],
#        [31337],
#        [27181],
#        [21508],
#        [17890],
#        [16244],
#        [15738],
#        [15379],
#        [15222],
#        [15230],
#        [15195],
#        [15143],
#        [15165],
#        [15070],
#        [15143],
#        [15276],
#        [15440],
#        [15558],
#        [15569],
#        [33944],
#        [33158],
#        [32830],
#        [32524],
#        [32301],
#        [31914],
#        [31897],
#        [32243],
#        [32709],
#        [33855],
#        [35837],
#        [41606],
#        [49045],
#        [52347],
#        [48723],
#        [39167],
#        [32297],
#        [28939],
#        [28124],
#        [27861],
#        [27988],
#        [28151],
#        [28242],
#        [28094],
#        [27847],
#        [27490],
#        [27344],
#        [27108],
#        [27020],
#        [26937],
#        [27075],
#        [27223],
#        [27305],
#        [27243],
#        [26913],
#        [26649],
#        [26415],
#        [26493],
#        [26550],
#        [26831],
#        [27506],
#        [28657],
#        [29746],
#        [28364],
#        [26922],
#        [25694],
#        [25136],
#        [24841],
#        [24479],
#        [24514],
#        [24428],
#        [24420],
#        [24261],
#        [24111],
#        [24092],
#        [24059],
#        [23893],
#        [23881],
#        [23883],
#        [24095],
#        [24392],
#        [25345],
#        [27014],
#        [29081],
#        [29405],
#        [27896],
#        [26203],
#        [24927],
#        [24377],
#        [23608],
#        [23290],
#        [23000],
#        [23035],
#        [23098],
#        [22867],
#        [22680],
#        [22736],
#        [22992],
#        [23056],
#        [23304],
#        [23435],
#        [23379],
#        [23380],
#        [23365],
#        [23329],
#        [23610],
#        [23792],
#        [24187],
#        [24546],
#        [25495],
#        [27761],
#        [33377],
#        [40928],
#        [58826],
#        [79014],
#        [89791],
#        [80894],
#        [62973],
#        [50076],
#        [42085],
#        [38883],
#        [38686],
#        [39382],
#        [40694],
#        [41509],
#        [42141],
#        [42499],
#        [42772],
#        [43064],
#        [43302],
#        [43175],
#        [43555],
#        [43892],
#        [43981],
#        [44098],
#        [44166],
#        [44124],
#        [44241],
#        [44234],
#        [44038],
#        [43889],
#        [43027],
#        [42172],
#        [41294],
#        [40314],
#        [39025],
#        [37520],
#        [36302],
#        [35656],
#        [35690],
#        [35616],
#        [35851],
#        [36364],
#        [37261],
#        [38345],
#        [40935],
#        [44102],
#        [50431],
#        [60486],
#        [69033],
#        [65338],
#        [52096],
#        [40828],
#        [33464],
#        [30057],
#        [28995],
#        [28329],
#        [28033],
#        [27780],
#        [27630],
#        [27676],
#        [27581],
#        [27490],
#        [27637],
#        [27640],
#        [27766],
#        [27832],
#        [27807],
#        [27940],
#        [28152],
#        [28378],
#        [28621],
#        [28959],
#        [29325],
#        [29572],
#        [29973],
#        [31123],
#        [32688],
#        [34680],
#        [34873],
#        [32794],
#        [30614],
#        [29558],
#        [29139],
#        [28455],
#        [27824],
#        [27129],
#        [26094],
#        [25507],
#        [25012],
#        [24615],
#        [24111],
#        [23664],
#        [23443],
#        [23140],
#        [23041],
#        [23216],
#        [24228],
#        [26225],
#        [27188],
#        [25981],
#        [24459],
#        [23435],
#        [22752],
#        [22377],
#        [22049],
#        [21905],
#        [21544],
#        [21151],
#        [20919],
#        [20774],
#        [20715],
#        [20731],
#        [20767],
#        [20843],
#        [20634],
#        [20435],
#        [20443],
#        [20491],
#        [20407],
#        [20392],
#        [20480],
#        [20583],
#        [21134],
#        [21841],
#        [24057],
#        [26880],
#        [36414],
#        [50582],
#        [70416],
#        [82469],
#        [76037],
#        [60648],
#        [48685],
#        [42280],
#        [37899],
#        [36953],
#        [36681],
#        [37115],
#        [37201],
#        [37433],
#        [37066],
#        [36624],
#        [36230],
#        [35799],
#        [35423],
#        [35097],
#        [34727],
#        [34511],
#        [34465],
#        [34554],
#        [34475],
#        [34440],
#        [34318],
#        [34130],
#        [33430],
#        [32566],
#        [31126],
#        [29520],
#        [27919],
#        [26664],
#        [25812],
#        [25169],
#        [24891],
#        [24849],
#        [25021],
#        [25089],
#        [25031],
#        [25169],
#        [25893],
#        [26914],
#        [29829],
#        [34374],
#        [41649],
#        [52051],
#        [60518],
#        [56616],
#        [43714],
#        [32643],
#        [24880],
#        [21988],
#        [20687],
#        [20436],
#        [19974],
#        [19479],
#        [19336],
#        [19158],
#        [19054],
#        [18914],
#        [18803],
#        [18925],
#        [19089],
#        [19216],
#        [19223],
#        [19299],
#        [19417],
#        [19670],
#        [20074],
#        [20260],
#        [20540],
#        [20874],
#        [21364],
#        [21937],
#        [23129],
#        [24982],
#        [25581],
#        [23959],
#        [22122],
#        [21206],
#        [20661],
#        [20473],
#        [20172],
#        [20112],
#        [20067],
#        [19871],
#        [19775],
#        [19818],
#        [19965],
#        [19912],
#        [19771],
#        [19576],
#        [19549],
#        [19550],
#        [19974],
#        [20887],
#        [22669],
#        [23698],
#        [23247],
#        [21633],
#        [20410],
#        [19688],
#        [19390],
#        [19239],
#        [19126],
#        [19068],
#        [18861],
#        [18683],
#        [18499],
#        [18404],
#        [18351],
#        [18402],
#        [18351],
#        [18214],
#        [18012],
#        [18038],
#        [17999],
#        [17950],
#        [17915],
#        [17994],
#        [18233],
#        [18606],
#        [19587],
#        [21894],
#        [26580],
#        [35412],
#        [48713],
#        [61297],
#        [63466],
#        [53385],
#        [42195],
#        [34918],
#        [30738],
#        [29298],
#        [29284],
#        [29501],
#        [29528],
#        [29488],
#        [29687],
#        [29792],
#        [29931],
#        [30302],
#        [30371],
#        [30146],
#        [29673],
#        [29530],
#        [29442],
#        [29248],
#        [28945],
#        [28752],
#        [28463],
#        [28101],
#        [27637],
#        [27264],
#        [26488],
#        [25800],
#        [25423],
#        [24995],
#        [24743],
#        [24384],
#        [24107],
#        [23510],
#        [22869],
#        [22586],
#        [22595],
#        [22835],
#        [23220],
#        [23961],
#        [25270],
#        [27420],
#        [32113],
#        [39333],
#        [49572],
#        [55801],
#        [48115],
#        [36325],
#        [27779],
#        [23117],
#        [21355],
#        [21021],
#        [20607],
#        [20283],
#        [19903],
#        [19678],
#        [19552],
#        [19478],
#        [19465],
#        [19576],
#        [19573],
#        [19594],
#        [19615],
#        [19651],
#        [19632],
#        [19690],
#        [19644],
#        [19802],
#        [20061],
#        [20229],
#        [20483],
#        [20842],
#        [21471],
#        [22118],
#        [23019],
#        [22979],
#        [22126],
#        [21265],
#        [20699],
#        [20449],
#        [20381],
#        [20338],
#        [20277],
#        [20223],
#        [20282],
#        [20395],
#        [20352],
#        [20272],
#        [20215],
#        [20249],
#        [20186],
#        [20180],
#        [20122],
#        [20132],
#        [20156],
#        [20141],
#        [20080],
#        [20047],
#        [19908],
#        [19788],
#        [19690],
#        [19588],
#        [19567],
#        [19538],
#        [19467],
#        [19443],
#        [19349],
#        [19342],
#        [19451],
#        [19451],
#        [19600],
#        [19571],
#        [19415],
#        [19224],
#        [19019],
#        [18974],
#        [19081],
#        [19163],
#        [19215],
#        [19175],
#        [19186],
#        [19166],
#        [19075],
#        [19096],
#        [19072],
#        [19031],
#        [19051],
#        [19007],
#        [19038],
#        [19076],
#        [18874],
#        [18798],
#        [18727],
#        [18774],
#        [18780],
#        [18865],
#        [19714],
#        [20983]], dtype=uint64)

# %% [markdown]
# Actually this should be done externally using my already built library. I'll just import cropping parameters to use as transformation values for the new labels.

# %%
NewLabs = sleap.Labels(skeletons=labels.skeletons)

# %%
# Get the path to all the videos in the /Users/ulric/Movies/TrainingVids/Crops folder
PathToCrops = Path("/Users/ulric/Movies/TrainingVids/Crops")
VidPaths = PathToCrops.rglob("*.mp4")
# Put the path to the videos in a list
CropVids = [vid for vid in VidPaths]
CropVids
# Out:
# [PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena6/Arena6.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena5/Arena5.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena2/Arena2.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena3/Arena3.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena4/Arena4.mp4')]

# %%
labels.videos
# Out:
# [Video(backend=HDF5Video(filename='/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp', dataset='video0/video', input_format='channels_last', convert_range=False))]

# %%
for v in CropVids:
    NewLabs.add_video(v)

NewLabs.videos
# Out:
# [PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena1/Arena1.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena6/Arena6.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena5/Arena5.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena2/Arena2.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena3/Arena3.mp4'),
#  PosixPath('/Users/ulric/Movies/TrainingVids/Crops/Arena4/Arena4.mp4')]

# %%
labels.labeled_frames[0]
# Out:
# LabeledFrame(video=HDF5Video('/Users/ulric/Documents/Documents/MaximeModel/LabeledFrames.train.pkg.slp'), frame_idx=6254, instances=6)

# %%
#For each frame split instances into separate labels
for f in range(len(labels)):
    frame = labels[f]
    for i in range(len(frame.instances)):
        Fly = frame.instances[i]
        NewLabs.add_instance(Fly, frame_idx=f)

# %% [markdown]
# Rotation of labes

# %%
frame0 = labels[0]

# %%
# rotate the points coordinates by 90 degrees
for i in range(len(frame0.instances)):
    Fly = frame0.instances[i]
    for p in range(len(Fly.points)):
        Fly.points[p].x, Fly.points[p].y = Fly.points[p].y, Fly.points[p].x
