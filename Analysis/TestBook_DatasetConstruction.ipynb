# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import pandas as pd
import os
from os import listdir
from os.path import isfile, join

import numpy as np
#import holoviews as hv
#from holoviews import opts
#hv.extension('bokeh')

# %%
filepath = '/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/Csvs/All/'
#outpath =
File = 'Ctrl_Starved_noWater_4.csv'

# %%
df = pd.read_csv(filepath+File)
df.head()
# Out:
#    Unnamed: 0  frame       pos_x       pos_y
# 0           0    3.0  384.322231  721.785442
# 1           1    4.0  384.317823  721.793244
# 2           2    5.0  384.400619  721.826783
# 3           3    6.0  384.525936  721.832275
# 4           4    7.0  384.332873  721.795792

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['pos_x'], df['pos_y'], c=df['frame'], alpha=0.5)
plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
#plt.gca().invert_yaxis()
plt.tight_layout()
#plt.savefig(path+'figs/trajectory.eps', format='eps', dpi=300)
plt.show()

plt.figure(figsize=(5,5))
plt.hist2d(df['pos_x'], df['pos_y'], bins=30, cmap='plasma')
plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
#plt.gca().invert_yaxis()

plt.tight_layout()

#plt.savefig(path+'figs/heatmap.eps', format='eps', dpi=300)
plt.show()

# %%
X = df['pos_x']
Y = df['pos_y']

# %%
df['pos_x'][3]
# Out:
# 384.5259362180759

# %%
X = df['pos_x']
Center_X = min(X)+((max(X)-min(X))/2)
Center_Y = min(Y)+((max(Y)-min(Y))/2)
Quarter_X = min(X)+((Center_X-min(X))/2)
TQuarter_X=Center_X+((max(X)-Center_X)/2)

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['pos_x'], df['pos_y'], c=df['frame'], alpha=0.5)
plt.plot(Center_X, Center_Y, 'xr')
plt.plot(Quarter_X, Center_Y, 'xr')
plt.plot(TQuarter_X, Center_Y, 'xr')
plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
#plt.gca().invert_yaxis()
plt.tight_layout()
#plt.savefig(path+'figs/trajectory.eps', format='eps', dpi=300)
plt.show()

# %%
rect = patches.Rectangle((250,300),50,50, edgecolor='r', facecolor="none") # (x,y), width, height

plt.figure(figsize=(5,5))
plt.scatter(df['pos_x'], df['pos_y'], c=df['frame'], alpha=0.5)
plt.plot(Center_X, Center_Y, 'xr')
plt.plot(Quarter_X, Center_Y, 'xr')
plt.plot(TQuarter_X, Center_Y, 'xr')
plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
#plt.gca().invert_yaxis()
plt.tight_layout()
#plt.savefig(path+'figs/trajectory.eps', format='eps', dpi=300)
plt.gca().add_patch(rect)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['pos_x'], df['pos_y'], c=df['frame'], alpha=0.5)
plt.plot(Center_X, Center_Y, 'xr')
plt.plot(Quarter_X, Center_Y, 'xr')
plt.plot(TQuarter_X, Center_Y, 'xr')
plt.vlines(x=[Center_X,Quarter_X,TQuarter_X], ymin=min(Y), ymax=max(Y), colors='red')
plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
#plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig("/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/Zones.eps", format='eps', dpi=300)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
Left = len(X[X<Center_X])
Right = len(X[X>Center_X])

Ratio  = (Left-Right)/(Left+Right)

# %%
xLin = np.linspace(min(X), max(X),100)
yLin = np.linspace(min(Y), max(Y), 100)
NegyLin = np.linspace(max(Y), min(Y), 100)

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['pos_x'], df['pos_y'], c=df['frame'], alpha=0.5)
plt.plot(Center_X, Center_Y, 'xr')
plt.plot(xLin,yLin, '-r')
plt.plot(xLin,NegyLin, '-r')
plt.xlabel('X', fontsize=16)
plt.ylabel('Y', fontsize=16)
#plt.gca().invert_yaxis()
plt.tight_layout()
#plt.savefig(path+'figs/trajectory.eps', format='eps', dpi=300)
plt.show()

# %%
Left = len(df['pos_x'][df['pos_x']<Center_X])
Right = len(df['pos_x'][df['pos_x']>Center_X])

# %%
Data = pd. DataFrame(columns=('Date','Training','Starvation','TimeLeft', 'TimeRight', 'PI'))

# %%
#Data['HemiLeft'] = [Left]
#Data['HemiRight'] = [Right]
Data['Performance'] = [(Left-Right)/(Left+Right)]

# %%
Data['HemiLeft'].add(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HemiLeft'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_23043/1858527937.py in <module>
# ----> 1 Data['HemiLeft'].add(4)
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'HemiLeft'

# %% [markdown]
# To do : Test 832x832 scale
# Find out how to attribute each frame position to a specific arena area.

# %%
# Gather csv files and give them actionnable names

#os.system("find /Volumes/Universal_HD/VideoAnalysis/GatedArenas/220304/Ctrl/Starved_noWater -name '*.csv'")

os.system("echo for file in /Volumes/Universal_HD/VideoAnalysis/GatedArenas/220304/Ctrl/Starved_noWater/*/*.csv; cp '$file' '/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/Csvs/Ctrl_noWater/Tracking_%.csv'")
# Out:
# for file in /Volumes/Universal_HD/VideoAnalysis/GatedArenas/220304/Ctrl/Starved_noWater/*/*.csv
# cp: $file: No such file or directory
# 256

# %%
# Create a csv table

Data = pd. DataFrame(columns=('Date','Training','Starvation', 'Performance'))

#Data. to_csv('/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/Estimates.csv')

# %%
from os import walk

f = []
for (dirpath, dirnames, filenames) in walk(filepath):
    f.extend(filenames)
    break

# %%
f[1]
# Out:
# 'Ctrl_Starved_noWater_2.csv'

# %%
Data_old = pd. DataFrame(columns=('Date','Training','Starvation', 'Relative Time Left', 'Relative Time Right','Relative Time far Left', 'Relative Time far Right'))

for file in f :
    Out = []
    df = pd.read_csv(filepath+file)
    X = df['pos_x']
    Center_X = min(X)+((max(X)-min(X))/2)
    Center_Y = min(Y)+((max(Y)-min(Y))/2)
    Quarter_X = min(X)+((Center_X-min(X))/2)
    TQuarter_X=Center_X+((max(X)-Center_X)/2)

    Left = len(X[X<Center_X])
    FarLeft = len(X[X<Quarter_X])
    Right = len(X[X>Center_X])
    FarRight = len(X[X>TQuarter_X])

    RelTimeLeft = Left / len(X)
    RelTimeFarLeft = FarLeft / len(X)
    RelTimeRight = Right / len(X)
    RelTimeFarRight = FarRight / len(X)

    Out.append(
        {
            'Date': "22-03-04" if any(x in file for x in ('1', '2', '3')) else "22-03-10",
            'Training' : 'Trained' if ('Trained' in file) else 'Ctrl',
            'Starvation' : 'Overnight no Water' if ('noWater' in file) else 'Overnight with Water',
            'Relative Time Left' : RelTimeLeft,
            'Relative Time Right' : RelTimeRight,
            'Relative Time far Left' : RelTimeFarLeft,
            'Relative Time far Right' : RelTimeFarRight

        }
    )
    Out = pd.DataFrame(Out)
    Data_old = Data_old.append(Out)
# Out:
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/2576423224.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data_old = Data_old.append(Out)

# %%
DataPath = "/Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar"
Data = pd. DataFrame(columns=('Date','Training','Starvation', 'Relative Time Left', 'Relative Time Right','Relative Time far Left', 'Relative Time far Right'))

for dirpath, dirnames, filenames in os.walk(DataPath):
    if 'Results' in dirnames:
        dirnames.remove('Results')
    for filename in [f for f in filenames if f.endswith(".csv")]:
        print (dirpath)

        Out = []
        file_path = os.path.join(dirpath, filename)
        print(file_path)
        df = pd.read_csv(file_path)
        X = df['pos_x']
        Y = df['pos_y']
        Center_X = min(X)+((max(X)-min(X))/2)
        Center_Y = min(Y)+((max(Y)-min(Y))/2)
        Quarter_X = min(X)+((Center_X-min(X))/2)
        TQuarter_X=Center_X+((max(X)-Center_X)/2)

        Left = len(X[X<Center_X])
        FarLeft = len(X[X<Quarter_X])
        Right = len(X[X>Center_X])
        FarRight = len(X[X>TQuarter_X])

        RelTimeLeft = Left / len(X)
        RelTimeFarLeft = FarLeft / len(X)
        RelTimeRight = Right / len(X)
        RelTimeFarRight = FarRight / len(X)

        VisitsLeft_gate = []

        timer=0

        for ypos in df.pos_y[df.pos_x<250] :
            if (ypos < 400 and ypos > 250) or (ypos < 600 and ypos > 475) in df.pos_y:
                timer += 1
                #print (timer)
            elif timer !=0 :
                VisitsLeft_gate.append(timer)
                timer = 0

        VisitsLeft_gate_Front = []

        timer=0

        for ypos in df.pos_y[(df.pos_x<350) & df.pos_x>200] :
            if (ypos < 500 and ypos > 300) in df.pos_y:
                timer += 1
                #print (timer)
            elif timer !=0 :
                VisitsLeft_gate_Front.append(timer)
                timer = 0

        VisitsRight_gate = []

        timer=0

        for ypos in df.pos_y[df.pos_x>575] :
            if (ypos < 400 and ypos > 250) or (ypos < 600 and ypos > 475) in df.pos_y:
                timer += 1
                #print (timer)
            elif timer !=0 :
                VisitsRight_gate.append(timer)
                timer = 0

        VisitsRight_gate_Front = []

        timer=0

        for ypos in df.pos_y[(df.pos_x>500) & (df.pos_x<650)] :
            if (ypos < 500 and ypos > 300) in df.pos_y:
                timer += 1
                #print (timer)
            elif timer !=0 :
                VisitsRight_gate_Front.append(timer)
                timer = 0

        VisitsTop_gate = []

        timer=0

        for xpos in df.pos_x[df.pos_y<275] :
            if (xpos < 350 and xpos > 250) or (xpos < 600 and xpos > 500) in df.pos_x:
                timer += 1
                #print (timer)
            elif timer !=0 :
                VisitsTop_gate.append(timer)
                timer = 0

        VisitsTop_gate_Front = []

        timer=0

        for xpos in df.pos_x[(df.pos_y<350) & (df.pos_y>200)] :
            if (xpos < 500 and xpos > 300) in df.pos_x:
                timer += 1
                #print (timer)
            elif timer !=0 :
                VisitsTop_gate_Front.append(timer)
                timer = 0

        Peeks_Left = sum(1 for i in VisitsLeft_gate if i > 160)
        Peeks_Right = sum(1 for i in VisitsRight_gate if i > 160)
        Peeks_Top = sum(1 for i in VisitsTop_gate if i > 160)
        LongPeeks_Left = sum(1 for i in VisitsLeft_gate if i > 320)
        LongPeeks_Right = sum(1 for i in VisitsRight_gate if i > 320)
        LongPeeks_Top = sum(1 for i in VisitsTop_gate if i > 320)
        Face_Left = sum(1 for i in VisitsLeft_gate_Front if i > 160)
        Face_Right = sum(1 for i in VisitsRight_gate_Front if i > 160)
        Face_Top = sum(1 for i in VisitsTop_gate_Front if i > 160)

        Out.append(
            {
                'Date': "22-03-04" if ('220304' in dirpath) else "22-03-10",
                'Training' : 'Trained' if ('Trained' in dirpath) else 'Ctrl',
                'Starvation' : 'Overnight no Water' if ('noWater' in dirpath) else 'Overnight with Water',
                'Reinforced_side' : 'Right' if ('RightRew' in dirpath) else 'Left' if ('LeftRew' in dirpath) else 'Empty',
                'Relative Time Left' : RelTimeLeft,
                'Relative Time Right' : RelTimeRight,
                'Relative Time far Left' : RelTimeFarLeft,
                'Relative Time far Right' : RelTimeFarRight,
                'Peeks Left' : Peeks_Left,
                'Peeks Right' : Peeks_Right,
                'Peeks Top' : Peeks_Top,
                'Face Left' : Face_Left,
                'Face Right' : Face_Right,
                'Face Top' : Face_Top,
                'Long Peeks Left' : LongPeeks_Left,
                'Long Peeks Right' : LongPeeks_Right,
                'Long Peeks Top' : LongPeeks_Top

            }
        )
        Out = pd.DataFrame(Out)
        Data = Data.append(Out)

Data.to_csv(DataPath + '/Results/DataSet.csv')
# Out:
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/093014_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/093014_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/100913_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/100913_s0a0_p0-0_LeftRew/Trained_Agar_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/104306_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/104306_s0a0_p0-0_LeftRew/Trained_Agar_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/085129_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar_Starved_noWater/085129_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/091847_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/091847_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/095737_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/095737_s0a0_p0-0_LeftRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/103201_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/103201_s0a0_p0-0_LeftRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/083724_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/083724_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/090326_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/090326_s0a0_p0-0_RightRew/Ctrl_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/094213_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/094213_s0a0_p0-0_LeftRew/Ctrl_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/102044_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/102044_s0a0_p0-0_LeftRew/Ctrl_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/082556_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Ctrl_Starved_noWater/082556_s0a0_p0-0_RightRew/Ctrl_Starved_noWater_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/111357_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/111357_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/110332_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/110332_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/101745_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/101745_s0a0_p0-0_LeftRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/100707_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Trained_Agar_Starved_noWater/100707_s0a0_p0-0_LeftRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/112430_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/112430_s0a0_p0-0_RightRew/Ctrl_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/103559_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/103559_s0a0_p0-0_LeftRew/Ctrl_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/104703_s0a0_p0-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/104703_s0a0_p0-0_RightRew/Ctrl_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/095456_s0a0_p0-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220708/Ctrl_Starved_noWater/095456_s0a0_p0-0_LeftRew/Ctrl_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/105643_s0a0_p6-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/105643_s0a0_p6-0_LeftRew/Trained_Starved_noWater_p6-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/114025_s0a0_p6-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/114025_s0a0_p6-0_RightRew/Trained_Starved_noWater_p6-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/124619_s0a0_p6-0_LeftRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/124619_s0a0_p6-0_LeftRew/Trained_Starved_noWater_p6-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/094913_s0a0_p6-0_RightRew
# /Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220407/Trained/Starved_noWater/094913_s0a0_p6-0_RightRew/Trained_Starved_noWater_p6-0_80fps_Trimmed_tracked.csv
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5185/3696887636.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data = Data.append(Out)

# %%
Data.head()
# Out:
#        Date Training            Starvation Relative Time Left  \
# 0  22-03-04     Ctrl    Overnight no Water           0.358036
# 0  22-03-04     Ctrl    Overnight no Water           0.557286
# 0  22-03-04     Ctrl    Overnight no Water           0.745746
# 0  22-03-04     Ctrl  Overnight with Water           0.515069
# 0  22-03-04     Ctrl  Overnight with Water           0.674293
#
#   Relative Time Right Relative Time far Left Relative Time far Right
# 0            0.641964               0.196914                0.354057
# 0            0.442714               0.478373                0.332078
# 0            0.254254               0.523853                0.174992
# 0            0.484931               0.357243                0.219925
# 0            0.325707               0.478666                0.024975

# %%
TestData = pd.read_csv('/Volumes/Universal_HD/VideoAnalysis/GatedArenas/DataSet.csv')
TestData.head()
# Out:
#    Unnamed: 0      Date Training            Starvation  Relative Time Left  \
# 0           0  22-03-04     Ctrl    Overnight no Water            0.358036
# 1           0  22-03-04     Ctrl    Overnight no Water            0.557286
# 2           0  22-03-04     Ctrl    Overnight no Water            0.745746
# 3           0  22-03-04     Ctrl  Overnight with Water            0.515069
# 4           0  22-03-04     Ctrl  Overnight with Water            0.674293
#
#    Relative Time Right  Relative Time far Left  Relative Time far Right
# 0             0.641964                0.196914                 0.354057
# 1             0.442714                0.478373                 0.332078
# 2             0.254254                0.523853                 0.174992
# 3             0.484931                0.357243                 0.219925
# 4             0.325707                0.478666                 0.024975

# %%
Partial = pd.DataFrame(Out)
Data.append(Partial)
# Out:
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_5116/726638824.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Data.append(Partial)
#        Date Training            Starvation Relative Time Left  \
# 0  22-03-04     Ctrl    Overnight no Water           0.358036
# 0  22-03-04     Ctrl    Overnight no Water           0.557286
# 0  22-03-04     Ctrl    Overnight no Water           0.745746
# 0  22-03-04     Ctrl  Overnight with Water           0.515069
# 0  22-03-04     Ctrl  Overnight with Water           0.674293
# 0  22-03-04     Ctrl  Overnight with Water           0.389869
# 0  22-03-04  Trained    Overnight no Water           0.581582
# 0  22-03-04  Trained    Overnight no Water           0.406953
# 0  22-03-04  Trained    Overnight no Water           0.590459
# 0  22-03-04  Trained  Overnight with Water           0.379803
# 0  22-03-04  Trained  Overnight with Water           0.597583
# 0  22-03-04  Trained  Overnight with Water           0.649248
# 0  22-03-04     Ctrl    Overnight no Water           0.182119
# 0  22-03-04     Ctrl    Overnight no Water           0.637576
# 0  22-03-04     Ctrl    Overnight no Water           0.491242
# 0  22-03-04     Ctrl    Overnight no Water           0.553834
# 0  22-03-04     Ctrl    Overnight no Water           0.704219
# 0  22-03-04     Ctrl  Overnight with Water           0.168639
# 0  22-03-04     Ctrl  Overnight with Water           0.414249
# 0  22-03-04     Ctrl  Overnight with Water           0.534949
# 0  22-03-04     Ctrl  Overnight with Water            0.38591
# 0  22-03-04     Ctrl  Overnight with Water           0.345411
# 0  22-03-04  Trained    Overnight no Water           0.273049
# 0  22-03-04  Trained    Overnight no Water           0.437071
# 0  22-03-04  Trained    Overnight no Water           0.787128
# 0  22-03-04  Trained    Overnight no Water           0.534065
# 0  22-03-04  Trained    Overnight no Water           0.360541
# 0  22-03-04  Trained    Overnight no Water           0.445535
# 0  22-03-04  Trained  Overnight with Water           0.305613
# 0  22-03-04  Trained  Overnight with Water           0.698724
# 0  22-03-04  Trained  Overnight with Water           0.561732
# 0  22-03-04  Trained  Overnight with Water           0.690113
# 0  22-03-04  Trained  Overnight with Water           0.551223
# 0  22-03-04  Trained  Overnight with Water           0.551223
#
#   Relative Time Right Relative Time far Left Relative Time far Right
# 0            0.641964               0.196914                0.354057
# 0            0.442714               0.478373                0.332078
# 0            0.254254               0.523853                0.174992
# 0            0.484931               0.357243                0.219925
# 0            0.325707               0.478666                0.024975
# 0            0.610131               0.076045                0.178429
# 0            0.418418               0.419449                0.331467
# 0            0.593047               0.236882                0.310992
# 0            0.409541               0.306701                0.194294
# 0            0.620197               0.147815                0.099749
# 0            0.402417               0.415091                0.253632
# 0            0.350752               0.439387                0.202745
# 0            0.817881               0.034786                0.358573
# 0            0.362424               0.291279                0.226502
# 0            0.508758               0.240094                0.273738
# 0            0.446166               0.457977                0.181692
# 0            0.295781               0.540781                 0.23062
# 0            0.831361               0.029412                0.201082
# 0            0.585751               0.178765                0.241021
# 0            0.465051               0.396522                0.382121
# 0             0.61409               0.083578                  0.4094
# 0            0.654589               0.223946                0.423827
# 0            0.726951               0.078226                 0.46603
# 0            0.562929               0.371174                 0.43326
# 0            0.212872               0.590593                 0.15028
# 0            0.465935               0.377869                0.348752
# 0            0.639459               0.252684                0.422734
# 0            0.554465               0.294812                0.441513
# 0            0.694387               0.193061                0.549139
# 0            0.301276               0.550865                0.166596
# 0            0.438268               0.153441                0.361568
# 0            0.309887               0.430544                0.136385
# 0            0.448777               0.220472                 0.27098
# 0            0.448777               0.220472                 0.27098

# %%
np.mean(Data['Relative Time Left'])
# Out:
# 0.5002688165350334

# %%
boxplotLeft =hv.BoxWhisker(Data,kdims=['Training', 'Starvation'],vdims=['Relative Time Left'])
boxplotLeft*hv.HLine(0.5).opts(
    opts.HLine(color='red',linewidth=4),
    opts.BoxWhisker(width=800, height=800)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_23043/1207014780.py in <module>
#       1 boxplotLeft =hv.BoxWhisker(Data,kdims=['Training', 'Starvation'],vdims=['Relative Time Left'])
#       2 boxplotLeft*hv.HLine(0.5).opts(
# ----> 3     opts.HLine(color='red',linewidth=4),
#       4     opts.BoxWhisker(width=800, height=800)
#       5 )
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/holoviews/util/__init__.py in builder(cls, spec, **kws)
#     502
#     503                 if reraise:
# --> 504                     raise ValueError(prefix + msg)
#     505
#     506             return Options(spec, **kws)
#
# ValueError: In opts.HLine(...), unexpected option 'linewidth' for HLine type across all extensions. Similar options for current extension ('bokeh') are: ['line_width', 'min_width', 'width'].

# %%
boxplotFarLeft =hv.BoxWhisker(Data,kdims=['Training'],vdims=['Relative Time Left'])
boxplotFarLeft.opts(width=800, height=800)
hv.save(boxplotFarLeft, "/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/boxplot.html", fmt='html')

# %%
boxplotFarRight =hv.BoxWhisker(Data,kdims=['Training', 'Starvation'],vdims=['Relative Time far Right'])
boxplotFarRight.opts(width=800, height=800)
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('Relative Time far Right', 1), ('Relative_Time_far_Right', 0), ('index', 1)
# :BoxWhisker   [Training,Starvation]   (Relative Time far Right)

# %%
Data['Starvation']
# Out:
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0      Overnight no Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# 0    Overnight with Water
# Name: Starvation, dtype: object

# %%
hv.save(boxplot, "/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/boxplot.html", fmt='html')

# %%
temp = Data.to_dict()

# %%
temp = pd.DataFrame(Data)

# %%
Data = Data.explode('Relative Time Left') # wtf
Data['Relative Time Left'] = Data['Relative Time Left'].astype('float')
violinLeft = hv.Violin(data=Data, kdims=['Training', 'Starvation', 'Date'], vdims=['Relative Time Left']).opts(
    cmap='Set1',
    split=hv.dim('Date'),
    #violin_color=hv.dim('Training'),
    height=800,
    width=1200,
    ylim=(0,1),
    fontsize={'title': 20, 'labels': 16, 'xticks': 12, 'yticks': 12}
)#.groupby(
  #  'Date'
#)
violinLeft
# Out:
# :Violin   [Training,Starvation,Date]   (Relative Time Left)

# %%
Data = Data.explode('Relative Time far Left') # wtf
Data['Relative Time far Left'] = Data['Relative Time far Left'].astype('float')

violinfarLeft = hv.Violin(data=Data, kdims=['Training', 'Starvation','Date'], vdims=['Relative Time far Left']).opts(
    cmap='Set1',
    split=hv.dim('Date'),
    #violin_color=hv.dim('Training'),
    height=800,
    width=1200,
    ylim=(0,1),
    fontsize={'title': 20, 'labels': 16, 'xticks': 12, 'yticks': 12}
)
violinfarLeft
# Out:
# :Violin   [Training,Starvation,Date]   (Relative Time far Left)

# %%
Data = Data.explode('Relative Time far Right') # wtf
Data['Relative Time far Right'] = Data['Relative Time far Right'].astype('float')

violinfarRight = hv.Violin(data=Data, kdims=['Training', 'Starvation','Date'], vdims=['Relative Time far Right']).opts(
    cmap='Set1',
    split=hv.dim('Date'),
    #violin_color=hv.dim('Training'),
    height=800,
    width=1200,
    ylim=(0,1),
    fontsize={'title': 20, 'labels': 16, 'xticks': 12, 'yticks': 12}
)
violinfarRight
# Out:
# :Violin   [Training,Starvation,Date]   (Relative Time far Right)

# %%
Data = Data.explode('Relative Time Right') # wtf
Data['Relative Time Right'] = Data['Relative Time Right'].astype('float')

violinRight = hv.Violin(data=Data, kdims=['Training', 'Starvation','Date'], vdims=['Relative Time Right']).opts(
    cmap='Set1',
    split=hv.dim('Date'),
    #violin_color=hv.dim('Training'),
    height=800,
    width=1200,
    ylim=(0,1),
    fontsize={'title': 20, 'labels': 16, 'xticks': 12, 'yticks': 12}
)
violinRight
# Out:
# :Violin   [Training,Starvation,Date]   (Relative Time Right)

# %%
layout = hv.Layout(violinLeft+violinRight+violinfarLeft+violinfarRight).cols(2)
layout
# Out:
# :Layout
#    .Violin.I   :Violin   [Training,Starvation,Date]   (Relative Time Left)
#    .Violin.II  :Violin   [Training,Starvation,Date]   (Relative Time Right)
#    .Violin.III :Violin   [Training,Starvation,Date]   (Relative Time far Left)
#    .Violin.IV  :Violin   [Training,Starvation,Date]   (Relative Time far Right)

# %%
hv.save(layout, "/Volumes/Universal_HD/VideoAnalysis/GatedArenas/Results/GatedArenas1.png", fmt='png')

# %%
import seaborn as sns

# %%
# Out:
# 0    0.358036
# 0    0.745746
# 0    0.557286
# 0    0.553834
# 0    0.704219
# 0    0.491242
# 0    0.182119
# 0    0.637576
# 0    0.674293
# 0    0.389869
# 0    0.515069
# 0    0.168639
# 0    0.534949
# 0     0.38591
# 0    0.414249
# 0    0.345411
# 0    0.581582
# 0    0.406953
# 0    0.590459
# 0    0.445535
# 0    0.360541
# 0    0.437071
# 0    0.787128
# 0    0.534065
# 0    0.273049
# 0    0.597583
# 0    0.649248
# 0    0.379803
# 0    0.690113
# 0    0.551223
# 0    0.698724
# 0    0.305613
# 0    0.561732
# Name: Relative Time Left, dtype: object

# %%
sns.boxplot(y=Data['Relative Time Left'])
# Out:
# <AxesSubplot:ylabel='Relative Time Left'>

# %%
Data = Data.explode('Relative Time Left') # wtf
Data['Relative Time Left'] = Data['Relative Time Left'].astype('float')

# %%
sns.violinplot(y=Data['Relative Time Left'], )
# Out:
# <AxesSubplot:ylabel='Relative Time Left'>

# %%
Melted = pd.melt(Data, value_name='Relative Time', var_name=['Training', 'Starvation', 'TimeType'])
Melted.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_1036/1309502414.py in <module>
# ----> 1 Melted = pd.melt(Data, value_name='Relative Time', var_name=['Training', 'Starvation', 'TimeType'])
#       2 Melted.head()
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     150         # has type "Series")
#     151         mdata[col] = np.asanyarray(  # type: ignore[assignment]
# --> 152             frame.columns._get_level_values(i)
#     153         ).repeat(N)
#     154
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_level_values(self, level)
#    2006         Index(['a', 'b', 'c'], dtype='object')
#    2007         """
# -> 2008         self._validate_index_level(level)
#    2009         return self
#    2010
#
# ~/opt/anaconda3/envs/TrackingAnalysis/lib/python3.9/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1925                 )
#    1926             elif level > 0:
# -> 1927                 raise IndexError(
#    1928                     f"Too many levels: Index has only 1 level, not {level + 1}"
#    1929                 )
#
# IndexError: Too many levels: Index has only 1 level, not 2

# %%
from os import walk

f = []
for (dirpath, dirnames, filenames) in walk(filepath):
    f.extend(filenames)
    break

# %%
Plots = []

from os import walk

f = []
for (dirpath, dirnames, filenames) in walk(filepath):
    f.extend(filenames)
    break
LenF = len(f)
for file in f :

    df = pd.read_csv(filepath+file)
    plt.figure(figsize=(5,5))
    plt.scatter(df['pos_x'], df['pos_y'], c=df['frame'], alpha=0.5)
    plt.xlabel('X', fontsize=16)
    plt.ylabel('Y', fontsize=16)
    #plt.gca().invert_yaxis()
    plt.tight_layout()
    #plt.savefig(path+'figs/trajectory.eps', format='eps', dpi=300)
    plt.show()

    plt.figure(figsize=(5,5))
    plt.hist2d(df['pos_x'], df['pos_y'], bins=30, cmap='plasma')
    plt.xlabel('X', fontsize=16)
    plt.ylabel('Y', fontsize=16)
    #plt.gca().invert_yaxis()

    plt.tight_layout()
    Plots[f.index(file)] = plt
    #plt.savefig(path+'figs/heatmap.eps', format='eps', dpi=300)
    #plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3v/_y6xq12x6l96bm2kp__gv6z40000gn/T/ipykernel_17342/626892281.py in <module>
#      27
#      28     plt.tight_layout()
# ---> 29     Plots[f.index(file)] = plt
#      30     #plt.savefig(path+'figs/heatmap.eps', format='eps', dpi=300)
#      31     #plt.show()
#
# IndexError: list assignment index out of range

# %%
DataPath = "/Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar"
DataTest = pd.read_csv('/Volumes/Ramdya-Lab/DURRIEU_Matthias/Experimental_data/MultiSensory_Project/GatedArenas_Agar/220715/Trained_Agar/091847_s0a0_p0-0_RightRew/Trained_Agar_Starved_noWater_p0-0_80fps_Trimmed_tracked.csv')

# %%
DataTest
# Out:
#        Unnamed: 0    frame       pos_x       pos_y
# 0               0      3.0  393.930454  698.520958
# 1               1      4.0  393.828163  696.813502
# 2               2      5.0  393.749754  696.410345
# 3               3      6.0  394.153251  694.550014
# 4               4      7.0  393.795040  692.911911
# ...           ...      ...         ...         ...
# 47743       47743  47746.0  517.029054  267.204011
# 47744       47744  47747.0  513.392877  270.840225
# 47745       47745  47748.0  510.845966  274.500570
# 47746       47746  47749.0  507.412506  279.125952
# 47747       47747  47750.0  505.196675  282.319479
#
# [47748 rows x 4 columns]

# %%
VisitsLeft_gate_Front = []

timer=0

for ypos in df.pos_y[(df.pos_x<350) & (df.pos_x>200)] :
    if (ypos < 500 and ypos > 300):
        timer += 1
        #print (timer)
    elif timer !=0 :
        VisitsLeft_gate_Front.append(timer)
        timer = 0

VisitsLeft_gate_Front
# Out:
# [21,
#  79,
#  33,
#  1167,
#  538,
#  935,
#  42,
#  56,
#  2,
#  55,
#  92,
#  47,
#  54,
#  49,
#  49,
#  42,
#  42,
#  91,
#  66,
#  46,
#  47,
#  53,
#  43,
#  48,
#  39]

# %%
VisitsLeft_gate = []

timer=0

for ypos in df.pos_y[df.pos_x<250] :
    if (ypos < 400 and ypos > 250) or (ypos < 600 and ypos > 475) in df.pos_y:
        timer += 1
        #print (timer)
    elif timer !=0 :
        VisitsLeft_gate.append(timer)
        timer = 0

VisitsLeft_gate
# Out:
# [34, 39, 10, 78, 13, 88, 92, 230, 48, 149, 58, 62, 247, 109, 6]
