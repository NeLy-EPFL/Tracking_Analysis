# %% [markdown]
# # Generate generic elements

# %% [markdown]
# ## 1 Importing lib

# %%
import cv2
import skimage 
import matplotlib.pyplot as plt
import numpy as np
import time
import os

import sys
sys.path.insert(0, "..")

from im_processing_fct.functions import *

# %% [markdown]
# ## 2 Generic background elements generation

# %% [markdown]
# ### 2.1 Outer arena

# %% [markdown]
# #### 2.1.1 Read images

# %%
im_outer_arena_gray = []
im_outer_arena_path = im_bg_dir_path.joinpath("outer_arena")

# %%
im_outer_arena_nb = 0
for img in im_outer_arena_path.rglob('img_0.jpg'):
    im = cv2.imread(img.as_posix())
    im_outer_arena_gray.append(cv2.cvtColor(im, cv2.COLOR_BGR2GRAY))
    im_outer_arena_nb += 1

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_outer_arena_nb):
    plt.subplot(5, int(np.floor(im_outer_arena_nb/5+1)), i+1),
    plt.imshow(im_outer_arena_gray[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.1.2 Clean images

# %%
im_outer_arena_gray_clean = []

for i in range(im_outer_arena_nb):
    im_outer_arena_gray_clean.append(im_clean_contours(im_outer_arena_gray[i], "single_contour"))

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_outer_arena_nb):
    plt.subplot(5, int(np.floor(im_outer_arena_nb/5+1)), i+1), 
    plt.imshow(im_outer_arena_gray_clean[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.1.3 Template matching

# %%
#compute homography with respect to the first image                                                          
H_outer_arena = []
for i in range(1, im_outer_arena_nb):
    H_outer_arena.append(compute_homography_orb(im_outer_arena_gray_clean[i], im_outer_arena_gray_clean[0])) 
        
im_outer_arena_gray_clean_trans = compute_gen_im_template(im_outer_arena_gray_clean, H_outer_arena, im_outer_arena_nb)
im_outer_arena_gray_clean_trans_resized = cv2.resize(im_outer_arena_gray_clean_trans, 
                                            (int(im_outer_arena_gray_clean_trans.shape[1]/rescaling_factor),
                                             int(im_outer_arena_gray_clean_trans.shape[0]/rescaling_factor)), 
                                             interpolation = cv2.INTER_AREA)

im_outer_arena_gray_clean_trans_enhance = enhance_center(im_outer_arena_gray_clean_trans)
im_outer_arena_gray_clean_trans_unif = uniform_illumination(im_outer_arena_gray_clean_trans)

'''
cv2.imwrite("im_outer_arena.jpg", im_outer_arena_gray_clean_trans)
cv2.imwrite("im_outer_arena_enhance.jpg", im_outer_arena_gray_clean_trans_enhance)
cv2.imwrite("im_outer_arena_unif.jpg", im_outer_arena_gray_clean_trans_unif)
cv2.imwrite("im_outer_arena_resized.jpg", im_outer_arena_gray_clean_trans_resized)
'''

plt.figure()
plt.imshow(im_outer_arena_gray[0], cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_outer_arena_gray_clean_trans, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_outer_arena_gray_clean_trans_enhance, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_outer_arena_gray_clean_trans_unif, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_outer_arena_gray_clean_trans_resized, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ### 2.2 Rails

# %% [markdown]
# #### 2.2.1 Read images

# %%
#user defined
rail_nb = 3

im_rail_gray = []
im_rail_path = im_bg_dir_path.joinpath("rail")
im_rail_nb = 0

for dir_name in im_rail_path.rglob('*.PNG'):
    print (dir_name)
   # for img in (dir_name.glob('.PNG')):
    #    print (img)
    #for i in range(rail_nb):
    #    print(dir_name.rg)
# Out:
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail0/rail0.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail0/rail1.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail0/rail2.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail1/rail0.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail1/rail1.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail1/rail2.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail2/rail0.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail2/rail1.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail2/rail2.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail3/rail0.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail3/rail1.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail3/rail2.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail4/rail0.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail4/rail1.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail4/rail2.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail5/rail0.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail5/rail1.PNG
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/rail/rail5/rail2.PNG

# %%
for imgs in im_rail_path.rglob('*.PNG'):
    im = cv2.imread(imgs.as_posix())
    im_pad_dim_y = int(np.floor((im_outer_arena_gray[0].shape[1]-im.shape[1])/2))
    if ((250-im.shape[1])%2):
        im_pad_dim_y_2 = im_pad_dim_y + 1
    else:
        im_pad_dim_y_2 = im_pad_dim_y

    im_pad_dim_x = int(np.floor((im_outer_arena_gray[0].shape[1]-im.shape[0])/2))
    if ((250-im.shape[0])%2):
        im_pad_dim_x_2 = im_pad_dim_x + 1
    else:
        im_pad_dim_x_2 = im_pad_dim_x

    im_pad = cv2.copyMakeBorder(im, im_pad_dim_x, im_pad_dim_x_2, im_pad_dim_y, im_pad_dim_y_2, cv2.BORDER_CONSTANT, (0,0,0))
    im_rail_gray.append(cv2.cvtColor(im_pad, cv2.COLOR_BGR2GRAY))
    im_rail_nb += 1


f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_rail_nb):
    plt.subplot(5, int(np.floor(im_rail_nb/5+1)), i+1),
    plt.imshow(im_rail_gray[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ##### 2.2.2 Clean images

# %%
im_rail_gray_clean = []

for i in range(im_rail_nb):
    im_rail_gray_clean.append(im_clean_contours(im_rail_gray[i], "in_bet_two_contours", bin_thresh=40))

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_rail_nb):
    plt.subplot(5, int(np.floor(im_outer_arena_nb/5+1)), i+1), 
    plt.imshow(im_rail_gray_clean[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.2.2 Axes of inertia

# %%
im_rail_gray_clean_trans = compute_gen_im_inertia(im_rail_gray_clean, im_rail_nb)
im_rail_gray_clean_trans_resized = cv2.resize(im_rail_gray_clean_trans, 
                                            (int(im_rail_gray_clean_trans.shape[1]/rescaling_factor),
                                             int(im_rail_gray_clean_trans.shape[0]/rescaling_factor)), 
                                             interpolation = cv2.INTER_AREA)

im_rail_gray_clean_trans_enhance = enhance_center(im_rail_gray_clean_trans)
im_rail_gray_clean_trans_unif = uniform_illumination(im_rail_gray_clean_trans)

cv2.imwrite(save_data_path.joinpath("im_rail.jpg").as_posix(), im_rail_gray_clean_trans)
#cv2.imwrite("im_rail_enhance.jpg", im_rail_gray_clean_trans_enhance)
cv2.imwrite(save_data_path.joinpath("im_rail_unif.jpg").as_posix() , im_rail_gray_clean_trans_unif)
#cv2.imwrite("im_rail_resized.jpg", im_rail_gray_clean_trans_resized)

plt.figure()
plt.imshow(im_rail_gray_clean[0], cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_rail_gray_clean_trans, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_rail_gray_clean_trans_enhance, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_rail_gray_clean_trans_unif, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_rail_gray_clean_trans_resized, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ### 2.3 Doors

# %% [markdown]
# #### 2.3.1 Read images

# %%
im_door_path = im_bg_dir_path.joinpath("door")
im_door_path.iterdir()
# Out:
# <generator object Path.iterdir at 0x7fbb10af8510>

# %%
im_door_gray = []
im_door_path = im_bg_dir_path.joinpath("door")
im_door_nb = 0

for dirs in im_door_path.iterdir():
    im = cv2.imread(dirs.joinpath("img_0.jpg").as_posix())
    im_door_gray.append(cv2.cvtColor(im, cv2.COLOR_BGR2GRAY))
    im_door_nb += 1

    
f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_rail_nb):
    plt.subplot(5, int(np.floor(im_door_nb/5+1)), i+1), 
    plt.imshow(im_door_gray[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.3.2 Clean images

# %%
im_door_gray_clean = []

for i in range(im_door_nb):
    im_door_gray_clean.append(im_clean_contours(im_door_gray[i], "single_contour"))

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_door_nb):
    plt.subplot(5, int(np.floor(im_door_nb/5+1)), i+1), 
    plt.imshow(im_door_gray_clean[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.3.3 Template matching

# %%
#compute homography with respect to the first image                                                          
H_door = []
for i in range(1, im_door_nb):
    H_door.append(compute_homography_orb(im_door_gray_clean[i], im_door_gray_clean[0])) 
        
im_door_gray_clean_trans = compute_gen_im_template(im_door_gray_clean, H_door, im_door_nb)
im_door_gray_clean_trans_resized = cv2.resize(im_door_gray_clean_trans, 
                                            (int(im_door_gray_clean_trans.shape[1]/rescaling_factor),
                                             int(im_door_gray_clean_trans.shape[0]/rescaling_factor)), 
                                             interpolation = cv2.INTER_AREA)

im_door_gray_clean_trans_enhance = enhance_center(im_door_gray_clean_trans)
im_door_gray_clean_trans_unif = uniform_illumination(im_door_gray_clean_trans)
'''
cv2.imwrite("im_door.jpg", im_door_gray_clean_trans)
cv2.imwrite("im_door_enhance.jpg", im_door_gray_clean_trans_enhance)
cv2.imwrite("im_door_unif.jpg", im_door_gray_clean_trans_unif)
cv2.imwrite("im_door_resized.jpg", im_door_gray_clean_trans_resized)
'''
plt.figure()
plt.imshow(im_door_gray_clean[0], cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_door_gray_clean_trans, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_door_gray_clean_trans_enhance, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_door_gray_clean_trans_unif, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_door_gray_clean_trans_resized, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ## 2.4 Arena and door

# %% [markdown]
# #### 2.4.1 Read images

# %%
im_arena_door_gray = []
im_arena_door_path = im_bg_dir_path.joinpath("arena_door/")
im_arena_door_nb = 0
for dirs in im_arena_door_path.iterdir():
    im = cv2.imread(dirs.joinpath("img_0.jpg").as_posix())
    im_arena_door_gray.append(cv2.cvtColor(im, cv2.COLOR_BGR2GRAY))
    im_arena_door_nb += 1

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_arena_door_nb):
    plt.subplot(5, int(np.floor(im_arena_door_nb/5+1)), i+1), 
    plt.imshow(im_arena_door_gray[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.4.2 Clean images

# %%
im_arena_door_gray_clean = []

for i in range(im_arena_door_nb):
    im_arena_door_gray_clean.append(im_clean_contours(im_arena_door_gray[i], "single_contour"))

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_arena_door_nb):
    plt.subplot(5, int(np.floor(im_arena_door_nb/5+1)), i+1), 
    plt.imshow(im_arena_door_gray_clean[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.4.3 Template matching

# %%
#compute homography with respect to the first image                                                          
H_arena_door = []
for i in range(1, im_arena_door_nb):
    H_arena_door.append(compute_homography_orb(im_arena_door_gray_clean[i], im_arena_door_gray_clean[0])) 
        
im_arena_door_gray_clean_trans = compute_gen_im_template(im_arena_door_gray_clean, H_arena_door, im_arena_door_nb)
im_arena_door_gray_clean_trans_resized = cv2.resize(im_arena_door_gray_clean_trans, 
                                            (int(im_arena_door_gray_clean_trans.shape[1]/rescaling_factor),
                                             int(im_arena_door_gray_clean_trans.shape[0]/rescaling_factor)), 
                                             interpolation = cv2.INTER_AREA)

im_arena_door_gray_clean_trans_enhance = enhance_center(im_arena_door_gray_clean_trans)
im_arena_door_gray_clean_trans_unif = uniform_illumination(im_arena_door_gray_clean_trans)


cv2.imwrite(save_data_path.joinpath("im_arena_door.jpg").as_posix(), im_arena_door_gray_clean_trans)
#cv2.imwrite("im_arena_door_enhance.jpg", im_arena_door_gray_clean_trans_enhance)
cv2.imwrite(save_data_path.joinpath("im_arena_door_unif.jpg").as_posix(), im_arena_door_gray_clean_trans_unif)
#cv2.imwrite("im_arena_door_resized.jpg", im_arena_door_gray_clean_trans_resized)

plt.figure()
plt.imshow(im_arena_door_gray[0], cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_arena_door_gray_clean_trans, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_arena_door_gray_clean_trans_enhance, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_arena_door_gray_clean_trans_unif, cmap='gray', vmin=0, vmax=255)
plt.figure()
plt.imshow(im_arena_door_gray_clean_trans_resized, cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ### 2.5 MultiMaze Bisymmetrical

# %% [markdown]
# #### 2.5.1 Read images

# %%
#How many  arenas and where to find the imgs
arenas_nb = 6

im_multimazebis_gray = []
im_multimazebis_path = im_bg_dir_path.joinpath("outer_arena_MultimazeBiS")
im_arenas_nb = 0

for dir_name in im_multimazebis_path.rglob('*.jpg'):
    print (dir_name)
   # for img in (dir_name.glob('.PNG')):
    #    print (img)
    #for i in range(rail_nb):
    #    print(dir_name.rg)
# Out:
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_0.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_1.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_2.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_3.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_4.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_5.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_6.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_7.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_8.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_9.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_10.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_11.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_12.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_13.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_14.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_15.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_16.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_17.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_18.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_19.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_20.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_21.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_22.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_23.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_24.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_25.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_26.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_27.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_28.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_29.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_30.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_31.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_32.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_33.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_34.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_35.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_36.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_37.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_38.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_39.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_40.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_41.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_42.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_43.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_44.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_45.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_46.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_47.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_48.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_49.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_50.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_51.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_52.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_53.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_54.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_55.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_56.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_57.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_58.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_59.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_60.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_61.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_62.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_63.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_64.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_65.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_66.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_67.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_68.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_69.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_70.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_71.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_72.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_73.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_74.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_75.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_76.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_77.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_78.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal3/images_40fps/img_79.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_0.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_1.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_2.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_3.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_4.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_5.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_6.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_7.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_8.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_9.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_10.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_11.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_12.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_13.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_14.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_15.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_16.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_17.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_18.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_19.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_20.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_21.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_22.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_23.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_24.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_25.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_26.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_27.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_28.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_29.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_30.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_31.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_32.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_33.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_34.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_35.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_36.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_37.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_38.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_39.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_40.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_41.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_42.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_43.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_44.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_45.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_46.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_47.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_48.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_49.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_50.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_51.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_52.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_53.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_54.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_55.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_56.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_57.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_58.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_59.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_60.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_61.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_62.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_63.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_64.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_65.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_66.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_67.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_68.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_69.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_70.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_71.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_72.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_73.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_74.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_75.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_76.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_77.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_78.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_79.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_0.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_1.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_2.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_3.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_4.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_5.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_6.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_7.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_8.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_9.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_10.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_11.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_12.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_13.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_14.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_15.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_16.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_17.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_18.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_19.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_20.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_21.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_22.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_23.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_24.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_25.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_26.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_27.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_28.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_29.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_30.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_31.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_32.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_33.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_34.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_35.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_36.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_37.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_38.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_39.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_40.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_41.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_42.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_43.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_44.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_45.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_46.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_47.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_48.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_49.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_50.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_51.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_52.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_53.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_54.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_55.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_56.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_57.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_58.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_59.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_60.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_61.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_62.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_63.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_64.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_65.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_66.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_67.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_68.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_69.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_70.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_71.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_72.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_73.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_74.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_75.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_76.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_77.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_78.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal2/images_40fps/img_79.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_0.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_1.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_2.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_3.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_4.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_5.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_6.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_7.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_8.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_9.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_10.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_11.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_12.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_13.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_14.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_15.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_16.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_17.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_18.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_19.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_20.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_21.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_22.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_23.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_24.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_25.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_26.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_27.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_28.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_29.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_30.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_31.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_32.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_33.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_34.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_35.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_36.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_37.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_38.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_39.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_40.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_41.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_42.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_43.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_44.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_45.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_46.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_47.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_48.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_49.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_50.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_51.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_52.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_53.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_54.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_55.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_56.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_57.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_58.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_59.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_60.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_61.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_62.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_63.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_64.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_65.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_66.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_67.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_68.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_69.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_70.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_71.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_72.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_73.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_74.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_75.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_76.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_77.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_78.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal4/images_40fps/img_79.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_0.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_1.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_2.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_3.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_4.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_5.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_6.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_7.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_8.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_9.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_10.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_11.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_12.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_13.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_14.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_15.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_16.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_17.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_18.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_19.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_20.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_21.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_22.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_23.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_24.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_25.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_26.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_27.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_28.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_29.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_30.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_31.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_32.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_33.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_34.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_35.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_36.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_37.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_38.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_39.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_40.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_41.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_42.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_43.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_44.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_45.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_46.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_47.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_48.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_49.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_50.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_51.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_52.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_53.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_54.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_55.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_56.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_57.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_58.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_59.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_60.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_61.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_62.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_63.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_64.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_65.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_66.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_67.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_68.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_69.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_70.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_71.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_72.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_73.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_74.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_75.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_76.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_77.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_78.jpg
# /mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Horizontal1/images_40fps/img_79.jpg

# %%
MulTest = cv2.imread('/mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_57.jpg')
plt.imshow(MulTest)
# Out:
# [ WARN:0@18.711] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_57.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [2], line 2
#       1 MulTest = cv2.imread('/mnt/labserver/DURRIEU_Matthias/Experimental_data/TrackingFiles/BackgroundImages/outer_arena_MultimazeBiS/Vertical1/images_40fps/img_57.jpg')
# ----> 2 plt.imshow(MulTest)
#
# File ~/miniconda3/envs/Main/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Main/lib/python3.10/site-packages/matplotlib/pyplot.py:2650, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2644 @_copy_docstring_and_deprecators(Axes.imshow)
#    2645 def imshow(
#    2646         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2647         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2648         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2649         resample=None, url=None, data=None, **kwargs):
# -> 2650     __ret = gca().imshow(
#    2651         X, cmap=cmap, norm=norm, aspect=aspect,
#    2652         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2653         vmax=vmax, origin=origin, extent=extent,
#    2654         interpolation_stage=interpolation_stage,
#    2655         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2656         url=url, **({"data": data} if data is not None else {}),
#    2657         **kwargs)
#    2658     sci(__ret)
#    2659     return __ret
#
# File ~/miniconda3/envs/Main/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/Main/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/Main/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5487, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5480 self.set_aspect(aspect)
#    5481 im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5482                       origin, extent, filternorm=filternorm,
#    5483                       filterrad=filterrad, resample=resample,
#    5484                       interpolation_stage=interpolation_stage,
#    5485                       **kwargs)
# -> 5487 im.set_data(X)
#    5488 im.set_alpha(alpha)
#    5489 if im.get_clip_path() is None:
#    5490     # image does not already have clipping set, clip to axes patch
#
# File ~/miniconda3/envs/Main/lib/python3.10/site-packages/matplotlib/image.py:706, in _ImageBase.set_data(self, A)
#     702 self._A = cbook.safe_masked_invalid(A, copy=True)
#     704 if (self._A.dtype != np.uint8 and
#     705         not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 706     raise TypeError("Image data of dtype {} cannot be converted to "
#     707                     "float".format(self._A.dtype))
#     709 if self._A.ndim == 3 and self._A.shape[-1] == 1:
#     710     # If just one dimension assume scalar and apply colormap
#     711     self._A = self._A[:, :, 0]
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
Landmark1 = np.floor(832/6)

crop1 = MulTest[:,:138]
plt.imshow(crop1)

# %%
MulTest[100, :]
# Out:
# array([[12, 12, 12],
#        [12, 12, 12],
#        [14, 14, 14],
#        ...,
#        [15, 15, 15],
#        [15, 15, 15],
#        [15, 15, 15]], dtype=uint8)

# %%
for i in range(MulTest.shape[1]):
    if MulTest[100, i,0] > 60:
        print(i)
# Out:
# 172
# 173
# 191
# 192
# 193
# 194
# 195
# 196
# 298
# 299
# 300
# 318
# 319
# 320
# 321
# 322
# 425
# 426
# 427
# 428
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 551
# 552
# 553
# 554
# 568
# 569
# 570
# 571
# 572
# 573
# 676
# 677
# 678
# 697
# 698
# 699
# 804

# %%
crop0 = MulTest[:,60:175]
crop1 = MulTest[:,180:305]
crop2 = MulTest[:,315:430]
crop3 = MulTest[:,435:555]
crop4 = MulTest[:,565:685]
crop5 = MulTest[:,695:810]
#plt.imshow(crop1)
#plt.imshow(crop2)
#plt.imshow(crop3)
plt.imshow(crop5)
#plt.imshow(crop0)

# %%
for imgs in im_multimazebis_path.rglob('*.jpg'):
    im = cv2.imread(imgs.as_posix())
    im_pad_dim_y = int(np.floor((im_outer_arena_gray[0].shape[1]-im.shape[1])/2))
    if('Horizontal' in imgs.as_posix()):
        im_pad_dim_x =

    if ((250-im.shape[1])%2):
        im_pad_dim_y_2 = im_pad_dim_y + 1
    else:
        im_pad_dim_y_2 = im_pad_dim_y

    im_pad_dim_x = int(np.floor((im_outer_arena_gray[0].shape[1]-im.shape[0])/2))
    if ((250-im.shape[0])%2):
        im_pad_dim_x_2 = im_pad_dim_x + 1
    else:
        im_pad_dim_x_2 = im_pad_dim_x

    im_pad = cv2.copyMakeBorder(im, im_pad_dim_x, im_pad_dim_x_2, im_pad_dim_y, im_pad_dim_y_2, cv2.BORDER_CONSTANT, (0,0,0))
    im_multimazebis_gray.append(cv2.cvtColor(im_pad, cv2.COLOR_BGR2GRAY))
    im_arenas_nb += 1


f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_rail_nb):
    plt.subplot(5, int(np.floor(im_arenas_nb/5+1)), i+1),
    plt.imshow(im_multimazebis_gray[i], cmap='gray', vmin=0, vmax=255)

# %%
im_arenas_nb = 0
for img in im_multimazebis_path.rglob('*.jpg'):
    im = cv2.imread(img.as_posix())
    im_multimazebis_gray.append(cv2.cvtColor(im, cv2.COLOR_BGR2GRAY))
    im_arenas_nb += 1

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)
for i in range(im_arenas_nb):
    plt.subplot(5, int(np.floor(im_arenas_nb/5+1)), i+1),
    plt.imshow(im_multimazebis_gray[i], cmap='gray', vmin=0, vmax=255)

# %%
numb = 10
for i in range(0,numb):
    plt.subplot(5, int(np.floor(numb/5+1)), i+1),
    plt.imshow(im_multimazebis_gray[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# #### 2.5.2 Clean images

# %%
im_multimazebis_gray_clean = []

for i in range(im_arenas_nb):
    im_multimazebis_gray_clean.append(im_clean_contours(im_multimazebis_gray[i], "single_contour"))

f = plt.figure()
f.set_figheight(12)
f.set_figwidth(12)

numb = 10
for i in range(0,numb):
    plt.subplot(5, int(np.floor(numb/5+1)), i+1),
    plt.imshow(im_multimazebis_gray_clean[i], cmap='gray', vmin=0, vmax=255)
#for i in range(im_outer_arena_nb):
#    plt.subplot(5, int(np.floor(im_outer_arena_nb/5+1)), i+1),
#    plt.imshow(im_outer_arena_gray_clean[i], cmap='gray', vmin=0, vmax=255)

# %% [markdown]
# ## 3 Generic foreground elements generation

# %% [markdown]
# ### 3.1 Glass Ball

# %% [markdown]
# #### 3.1.1 Read image

# %%
im_ball_path = im_fg_dir_path.joinpath("ball0")
im_ball = cv2.imread(im_ball_path.joinpath("img_0.jpg").as_posix())
im_ball_gray = cv2.cvtColor(im_ball, cv2.COLOR_BGR2GRAY)

plt.figure()
plt.imshow(im_ball_gray, cmap='gray', vmin=0, vmax=255)

ball_gray = im_ball_gray[445:505, 426:486]

#has to be centered
plt.figure()
plt.imshow(ball_gray, cmap='gray', vmin=0, vmax=255)

#ball_gray_clean = im_clean_contours(ball_gray, "in_bet_two_contours", dil_kernel = np.ones((1,1), np.uint8), 
#                                    bin_thresh = 100)

#plt.figure()
#plt.imshow(ball_gray_clean, cmap='gray', vmin=0, vmax=255)

_, ball_gray_clean_bin = cv2.threshold(ball_gray, 215, 255, cv2.THRESH_BINARY)

plt.figure()
plt.imshow(ball_gray_clean_bin, cmap='gray', vmin=0, vmax=255)

plt.figure()
plt.imshow(cv2.resize(ball_gray_clean_bin,(int(ball_gray_clean_bin.shape[1]/rescaling_factor),
                                           int(ball_gray_clean_bin.shape[0]/rescaling_factor)), 
                                           interpolation = cv2.INTER_AREA), cmap='gray', vmin=0, vmax=255)

cv2.imwrite(save_data_path.joinpath("im_ball.jpg").as_posix(), ball_gray_clean_bin)
# Out:
# True

# %% [markdown]
# ### 3.2 1.5mm Steel ball

# %% [markdown]
# #### 3.1.1 Read image

# %%
im_ball_path = im_fg_dir_path.joinpath("ball0")
im_ball = cv2.imread(im_ball_path.joinpath("img_0.jpg").as_posix())
im_ball_gray = cv2.cvtColor(im_ball, cv2.COLOR_BGR2GRAY)

plt.figure()
plt.imshow(im_ball_gray, cmap='gray', vmin=0, vmax=255)

# %%
BallPath = im_fg_dir_path.joinpath("SteelBall15_0")
Ball = cv2.imread(BallPath.joinpath("SteelBall15_0.png").as_posix())
#has to be centered
plt.figure()
plt.imshow(Ball, cmap='gray', vmin=0, vmax=255)

#ball_gray_clean = im_clean_contours(ball_gray, "in_bet_two_contours", dil_kernel = np.ones((1,1), np.uint8),
#                                    bin_thresh = 100)

#plt.figure()
#plt.imshow(ball_gray_clean, cmap='gray', vmin=0, vmax=255)

# %%
_, ball_gray_clean_bin = cv2.threshold(Ball, 180, 255, cv2.THRESH_BINARY)

plt.figure()
plt.imshow(ball_gray_clean_bin, cmap='gray', vmin=0, vmax=255)

# %%
plt.figure()
plt.imshow(cv2.resize(ball_gray_clean_bin,(int(ball_gray_clean_bin.shape[1]/rescaling_factor),
                                           int(ball_gray_clean_bin.shape[0]/rescaling_factor)),
                                           interpolation = cv2.INTER_AREA), cmap='gray', vmin=0, vmax=255)

cv2.imwrite(save_data_path.joinpath("im_steelball15.jpg").as_posix(), ball_gray_clean_bin)
# Out:
# True

# %% [markdown]
# TBC
